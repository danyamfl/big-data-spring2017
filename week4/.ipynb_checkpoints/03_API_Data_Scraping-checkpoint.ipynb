# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[40.261455,-76.882553] # Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': {'coordinates': [-76.92590021, 40.2716516], 'type': 'Point'},
#   'created_at': 'Mon Mar 06 13:21:58 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'swarmapp.com/c/6G67HDOFpmG',
#      'expanded_url': 'https://www.swarmapp.com/c/6G67HDOFpmG',
#      'indices': [61, 84],
#      'url': 'https://t.co/6YGtjRNegX'}],
#    'user_mentions': [{'id': 71139801,
#      'id_str': '71139801',
#      'indices': [37, 43],
#      'name': 'EPASD',
#      'screen_name': 'EPASD'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [40.2716516, -76.92590021], 'type': 'Point'},
#   'id': 838741445444046848,
#   'id_str': '838741445444046848',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-80.519851, 39.719801],
#       [-74.689517, 39.719801],
#       [-74.689517, 42.516072],
#       [-80.519851, 42.516072]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Pennsylvania, USA',
#    'id': 'dd9c503d6c35364b',
#    'name': 'Pennsylvania',
#    'place_type': 'admin',
#    'url': 'https://api.twitter.com/1.1/geo/id/dd9c503d6c35364b.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://foursquare.com" rel="nofollow">Foursquare</a>',
#   'text': "I'm at West Creek Hills Elementary - @epasd in Camp Hill, PA https://t.co/6YGtjRNegX",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Sep 14 17:06:02 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "Beer snob, amateur photographer, facial hair groupie, techno geek, gamer gal, music whore & resident smartass. My snark is my own & not my employer's.",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 497,
#    'follow_request_sent': None,
#    'followers_count': 373,
#    'following': None,
#    'friends_count': 267,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 16284746,
#    'id_str': '16284746',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 17,
#    'location': 'Pennsylvania',
#    'name': 'Draven',
#    'notifications': None,
#    'profile_background_color': 'ACDED6',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/720989120/e945bf3d3fe19e55ec3d47039807d883.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/720989120/e945bf3d3fe19e55ec3d47039807d883.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16284746/1353843784',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/830382518222352384/nruD1G_q_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830382518222352384/nruD1G_q_normal.jpg',
#    'profile_link_color': '038543',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '95E8EC',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'IamDraven',
#    'statuses_count': 12828,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:56 +0000 2017',
#   'entities': {'hashtags': [{'indices': [28, 37], 'text': 'giveaway'}],
#    'symbols': [],
#    'urls': [{'display_url': 'sensiblestylista.com/2017/03/us-giv…',
#      'expanded_url': 'http://www.sensiblestylista.com/2017/03/us-giveaway-win-shoes-of-your-choice.html',
#      'indices': [83, 106],
#      'url': 'https://t.co/VBbviCw76e'}],
#    'user_mentions': [{'id': 800656512,
#      'id_str': '800656512',
#      'indices': [6, 22],
#      'name': 'Kimberly Kong',
#      'screen_name': 'SensibleStylist'},
#     {'id': 770721708,
#      'id_str': '770721708',
#      'indices': [41, 53],
#      'name': 'GuiltySoles',
#      'screen_name': 'guiltysoles'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741436795355137,
#   'id_str': '838741436795355137',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "Enter @sensiblestylist's US #giveaway w/ @guiltysoles to win shoes of your choice! https://t.co/VBbviCw76e",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Mar 31 02:10:36 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Creator of Fashion + Advice Blog, Ask Away | Momma Of 4 Chihuahuas | Author of Fixing Your Finances',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'askawayblog.com',
#        'expanded_url': 'http://www.askawayblog.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/g9ZuvKnqnI'}]}},
#    'favourites_count': 342,
#    'follow_request_sent': None,
#    'followers_count': 7020,
#    'following': None,
#    'friends_count': 1024,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 27788572,
#    'id_str': '27788572',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 126,
#    'location': 'Harrisburg, Pennsylvania',
#    'name': 'Ellen Ross',
#    'notifications': None,
#    'profile_background_color': 'ABB8C2',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/484304032693882881/Y_RvMSYJ.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/484304032693882881/Y_RvMSYJ.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27788572/1404302168',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/714116298586849280/WXokCd1-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/714116298586849280/WXokCd1-_normal.jpg',
#    'profile_link_color': '9266CC',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'E69AD7',
#    'profile_text_color': 'A213BF',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ellen_ross1',
#    'statuses_count': 38669,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/g9ZuvKnqnI',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:53 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'fb.me/1OtlOVIrV',
#      'expanded_url': 'http://fb.me/1OtlOVIrV',
#      'indices': [0, 23],
#      'url': 'https://t.co/U1LMkVLFgM'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741427303645184,
#   'id_str': '838741427303645184',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'und',
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#   'text': 'https://t.co/U1LMkVLFgM',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jan 07 06:22:04 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Persistency ...',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'snuffysnu2u.com',
#        'expanded_url': 'http://snuffysnu2u.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/WfqdBsIHJS'}]}},
#    'favourites_count': 181,
#    'follow_request_sent': None,
#    'followers_count': 5503,
#    'following': None,
#    'friends_count': 1162,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 457263573,
#    'id_str': '457263573',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 7,
#    'location': 'New Cumberland, PA',
#    'name': 'Seanbarowskisr',
#    'notifications': None,
#    'profile_background_color': 'DBE9ED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/564400853/tour19.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/564400853/tour19.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/457263573/1422579180',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/739643912894173184/ExNO45BJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/739643912894173184/ExNO45BJ_normal.jpg',
#    'profile_link_color': '0099CC',
#    'profile_sidebar_border_color': 'FFF8AD',
#    'profile_sidebar_fill_color': 'F6FFD1',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Seanbarowskisr',
#    'statuses_count': 16633,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/WfqdBsIHJS',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:51 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 18227519,
#      'id_str': '18227519',
#      'indices': [0, 12],
#      'name': 'Mika Brzezinski',
#      'screen_name': 'morningmika'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741415874215936,
#   'id_str': '838741415874215936',
#   'in_reply_to_screen_name': 'morningmika',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 18227519,
#   'in_reply_to_user_id_str': '18227519',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@morningmika: Really nervous? So ironic after all you &amp; Joe did to get him on the ballot. Remember-you featured him every morning 4 ratings.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Oct 16 01:45:55 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'https://t.co/RI1qEBGUQ0  Carlisle Indian School Biographer / Getting the names to the nations.',
#    'entities': {'description': {'urls': [{'display_url': 'ciis.blogspot.com',
#        'expanded_url': 'http://www.ciis.blogspot.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/RI1qEBGUQ0'}]},
#     'url': {'urls': [{'display_url': 'carlisleindianschool.org',
#        'expanded_url': 'http://www.carlisleindianschool.org',
#        'indices': [0, 22],
#        'url': 'http://t.co/iKQHNwciqH'}]}},
#    'favourites_count': 328,
#    'follow_request_sent': None,
#    'followers_count': 145,
#    'following': None,
#    'friends_count': 597,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 16799487,
#    'id_str': '16799487',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'Carlisle, PA, USA',
#    'name': 'BarbaraKriete Landis',
#    'notifications': None,
#    'profile_background_color': '957097',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/15439052/9_entrance_pratt_ave.JPG',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/15439052/9_entrance_pratt_ave.JPG',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16799487/1439729902',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/824089947472822278/Ug-cRENE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/824089947472822278/Ug-cRENE_normal.jpg',
#    'profile_link_color': '542B21',
#    'profile_sidebar_border_color': '9286A6',
#    'profile_sidebar_fill_color': 'C7B3A0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'blandis',
#    'statuses_count': 597,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/iKQHNwciqH',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:46 +0000 2017',
#   'entities': {'hashtags': [{'indices': [93, 96], 'text': 'JY'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1080107773,
#      'id_str': '1080107773',
#      'indices': [3, 17],
#      'name': 'Jarrod Hill',
#      'screen_name': 'Trojans_Coach'},
#     {'id': 1025149687,
#      'id_str': '1025149687',
#      'indices': [31, 42],
#      'name': 'Cam',
#      'screen_name': 'moorecam28'},
#     {'id': 709733217,
#      'id_str': '709733217',
#      'indices': [43, 51],
#      'name': 'Brendan Shay',
#      'screen_name': 'bshay31'},
#     {'id': 3285889790,
#      'id_str': '3285889790',
#      'indices': [56, 68],
#      'name': 'MSMCC United Hockey',
#      'screen_name': 'CPIHLUnited'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741397398306816,
#   'id_str': '838741397398306816',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 4,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 02:35:16 +0000 2017',
#    'entities': {'hashtags': [{'indices': [74, 77], 'text': 'JY'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1025149687,
#       'id_str': '1025149687',
#       'indices': [12, 23],
#       'name': 'Cam',
#       'screen_name': 'moorecam28'},
#      {'id': 709733217,
#       'id_str': '709733217',
#       'indices': [24, 32],
#       'name': 'Brendan Shay',
#       'screen_name': 'bshay31'},
#      {'id': 3285889790,
#       'id_str': '3285889790',
#       'indices': [37, 49],
#       'name': 'MSMCC United Hockey',
#       'screen_name': 'CPIHLUnited'}]},
#    'favorite_count': 8,
#    'favorited': False,
#    'geo': None,
#    'id': 838578700627111937,
#    'id_str': '838578700627111937',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Congrats to @moorecam28 @bshay31 and @CPIHLUnited on their championship.  #JY is proud of what you have accomplished',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jan 11 15:52:10 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Head Coach Hershey High School Varsity Ice Hockey',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 66,
#     'follow_request_sent': None,
#     'followers_count': 155,
#     'following': None,
#     'friends_count': 270,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1080107773,
#     'id_str': '1080107773',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 3,
#     'location': 'Hershey, PA',
#     'name': 'Jarrod Hill',
#     'notifications': None,
#     'profile_background_color': 'DB921C',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/765366822/849020816968b869758948370638edb0.gif',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/765366822/849020816968b869758948370638edb0.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1080107773/1357925858',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3095131542/856433f73a3081ce9712fa1ed1fc6a15_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3095131542/856433f73a3081ce9712fa1ed1fc6a15_normal.png',
#     'profile_link_color': '0C0CF0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'Trojans_Coach',
#     'statuses_count': 217,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @Trojans_Coach: Congrats to @moorecam28 @bshay31 and @CPIHLUnited on their championship.  #JY is proud of what you have accomplished',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Nov 03 11:36:53 +0000 2016',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'This is the new and official Twitter feed of the Central Pennsylvania Interscholastic Hockey League. Follow us for updates on the 2016-17 hockey season.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'CPIHL.com',
#        'expanded_url': 'http://www.CPIHL.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/AyrVZsuoRB'}]}},
#    'favourites_count': 67,
#    'follow_request_sent': None,
#    'followers_count': 159,
#    'following': None,
#    'friends_count': 12,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 794141293966487552,
#    'id_str': '794141293966487552',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Pennsylvania, USA',
#    'name': 'CPIHL Hockey',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/794143643443613696/00e59p8p_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/794143643443613696/00e59p8p_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'CPIHLOfficial',
#    'statuses_count': 316,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/AyrVZsuoRB',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:46 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741394558709762,
#   'id_str': '838741394558709762',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '"THE JOULES OF ENERGYYYYYYYY🎶🎵🎶" ~Mr. Eshbach',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Apr 28 11:33:48 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'the wasian persuasion 👉👲🏻👉',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 478,
#    'follow_request_sent': None,
#    'followers_count': 102,
#    'following': None,
#    'friends_count': 243,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 725649208733274112,
#    'id_str': '725649208733274112',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Dover, PA',
#    'name': 'Jake Kistner',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/725649208733274112/1483544131',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/837305959898820608/NNxD7vZA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837305959898820608/NNxD7vZA_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'jacobrkister',
#    'statuses_count': 186,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:41 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'fb.me/69VG5PTPy',
#      'expanded_url': 'http://fb.me/69VG5PTPy',
#      'indices': [0, 23],
#      'url': 'https://t.co/u02nM2S4wx'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741376028262402,
#   'id_str': '838741376028262402',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'und',
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#   'text': 'https://t.co/u02nM2S4wx',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jan 07 06:22:04 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Persistency ...',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'snuffysnu2u.com',
#        'expanded_url': 'http://snuffysnu2u.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/WfqdBsIHJS'}]}},
#    'favourites_count': 181,
#    'follow_request_sent': None,
#    'followers_count': 5503,
#    'following': None,
#    'friends_count': 1162,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 457263573,
#    'id_str': '457263573',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 7,
#    'location': 'New Cumberland, PA',
#    'name': 'Seanbarowskisr',
#    'notifications': None,
#    'profile_background_color': 'DBE9ED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/564400853/tour19.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/564400853/tour19.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/457263573/1422579180',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/739643912894173184/ExNO45BJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/739643912894173184/ExNO45BJ_normal.jpg',
#    'profile_link_color': '0099CC',
#    'profile_sidebar_border_color': 'FFF8AD',
#    'profile_sidebar_fill_color': 'F6FFD1',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Seanbarowskisr',
#    'statuses_count': 16633,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/WfqdBsIHJS',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:38 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741363210522625,
#   'id_str': '838741363210522625',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#   'text': 'No one can touch us',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Apr 19 20:22:53 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Host of the new pop culture podcast "Shooting the Sh*t with Shann" for the popular and peons!!!! first episode coming soon',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'youtube.com/user/ShannBeezy',
#        'expanded_url': 'http://www.youtube.com/user/ShannBeezy',
#        'indices': [0, 23],
#        'url': 'https://t.co/0KG8AjUW7v'}]}},
#    'favourites_count': 149,
#    'follow_request_sent': None,
#    'followers_count': 603,
#    'following': None,
#    'friends_count': 1393,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 33302528,
#    'id_str': '33302528',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'York,PA',
#    'name': 'Doctyr Yamaguchi',
#    'notifications': None,
#    'profile_background_color': '0F0405',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/691802388/302b3e69aef1afc18e7557d82af71a25.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/691802388/302b3e69aef1afc18e7557d82af71a25.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33302528/1460065703',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/639205460005007360/libhuLha_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/639205460005007360/libhuLha_normal.jpg',
#    'profile_link_color': '4A0815',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '590B0B',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'FrankPetrelliYC',
#    'statuses_count': 7983,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/0KG8AjUW7v',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:37 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/vBfAc2IJ8w',
#      'expanded_url': 'https://twitter.com/beth_whistance/status/838736255294799872/photo/1',
#      'id': 838736246461591552,
#      'id_str': '838736246461591552',
#      'indices': [36, 59],
#      'media_url': 'http://pbs.twimg.com/media/C6PKLB6WcAAAAGb.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6PKLB6WcAAAAGb.jpg',
#      'sizes': {'large': {'h': 2002, 'resize': 'fit', 'w': 1126},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#       'small': {'h': 680, 'resize': 'fit', 'w': 382},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838736255294799872,
#      'source_status_id_str': '838736255294799872',
#      'source_user_id': 497377776,
#      'source_user_id_str': '497377776',
#      'type': 'photo',
#      'url': 'https://t.co/vBfAc2IJ8w'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 497377776,
#      'id_str': '497377776',
#      'indices': [3, 18],
#      'name': 'Beth Whistance',
#      'screen_name': 'beth_whistance'},
#     {'id': 220361522,
#      'id_str': '220361522',
#      'indices': [20, 35],
#      'name': 'Ryan',
#      'screen_name': 'ryanDNostalgia'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/vBfAc2IJ8w',
#      'expanded_url': 'https://twitter.com/beth_whistance/status/838736255294799872/photo/1',
#      'id': 838736246461591552,
#      'id_str': '838736246461591552',
#      'indices': [36, 59],
#      'media_url': 'http://pbs.twimg.com/media/C6PKLB6WcAAAAGb.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6PKLB6WcAAAAGb.jpg',
#      'sizes': {'large': {'h': 2002, 'resize': 'fit', 'w': 1126},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#       'small': {'h': 680, 'resize': 'fit', 'w': 382},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838736255294799872,
#      'source_status_id_str': '838736255294799872',
#      'source_user_id': 497377776,
#      'source_user_id_str': '497377776',
#      'type': 'photo',
#      'url': 'https://t.co/vBfAc2IJ8w'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741359477542912,
#   'id_str': '838741359477542912',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'und',
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 2,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 13:01:20 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/vBfAc2IJ8w',
#       'expanded_url': 'https://twitter.com/beth_whistance/status/838736255294799872/photo/1',
#       'id': 838736246461591552,
#       'id_str': '838736246461591552',
#       'indices': [16, 39],
#       'media_url': 'http://pbs.twimg.com/media/C6PKLB6WcAAAAGb.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PKLB6WcAAAAGb.jpg',
#       'sizes': {'large': {'h': 2002, 'resize': 'fit', 'w': 1126},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 382},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/vBfAc2IJ8w'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 220361522,
#       'id_str': '220361522',
#       'indices': [0, 15],
#       'name': 'Ryan',
#       'screen_name': 'ryanDNostalgia'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/vBfAc2IJ8w',
#       'expanded_url': 'https://twitter.com/beth_whistance/status/838736255294799872/photo/1',
#       'id': 838736246461591552,
#       'id_str': '838736246461591552',
#       'indices': [16, 39],
#       'media_url': 'http://pbs.twimg.com/media/C6PKLB6WcAAAAGb.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PKLB6WcAAAAGb.jpg',
#       'sizes': {'large': {'h': 2002, 'resize': 'fit', 'w': 1126},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 382},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/vBfAc2IJ8w'}]},
#    'favorite_count': 2,
#    'favorited': False,
#    'geo': None,
#    'id': 838736255294799872,
#    'id_str': '838736255294799872',
#    'in_reply_to_screen_name': 'ryanDNostalgia',
#    'in_reply_to_status_id': 838736081721917441,
#    'in_reply_to_status_id_str': '838736081721917441',
#    'in_reply_to_user_id': 220361522,
#    'in_reply_to_user_id_str': '220361522',
#    'is_quote_status': False,
#    'lang': 'und',
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 2,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '@ryanDNostalgia https://t.co/vBfAc2IJ8w',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Feb 19 22:49:15 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'dreaming dreams with happy endings #steelers #mufc',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 3599,
#     'follow_request_sent': None,
#     'followers_count': 199,
#     'following': None,
#     'friends_count': 640,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 497377776,
#     'id_str': '497377776',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1,
#     'location': 'Manchester/York',
#     'name': 'Beth Whistance',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/662032433/o15jmh9gxy77gjo9c8kv.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/662032433/o15jmh9gxy77gjo9c8kv.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/497377776/1395246360',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/643836916941651968/6QxrQTYR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/643836916941651968/6QxrQTYR_normal.jpg',
#     'profile_link_color': 'D6833A',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'beth_whistance',
#     'statuses_count': 1773,
#     'time_zone': 'Amsterdam',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 3600,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @beth_whistance: @ryanDNostalgia https://t.co/vBfAc2IJ8w',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Oct 01 14:12:54 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'left wing & intersectional feminist, glitter enthusiast',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 16261,
#    'follow_request_sent': None,
#    'followers_count': 2437,
#    'following': None,
#    'friends_count': 1016,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 856437704,
#    'id_str': '856437704',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 12,
#    'location': 'manchester (she/her)',
#    'name': 'marcy',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/458167227691184128/WUaaNTGF.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/458167227691184128/WUaaNTGF.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/856437704/1466501817',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/797865384003125248/R_g5uv3k_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/797865384003125248/R_g5uv3k_normal.jpg',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Marxelina4',
#    'statuses_count': 47524,
#    'time_zone': 'London',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 0,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:30 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1276754558,
#      'id_str': '1276754558',
#      'indices': [15, 29],
#      'name': 'bells',
#      'screen_name': 'bellaaguirre3'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741327357456385,
#   'id_str': '838741327357456385',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Happy Birthday @bellaaguirre3 ! Iove you pretty girl, I hope you have an amazing day! 💓🎉😊',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Dec 29 00:20:31 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Let go, and let God.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 678,
#    'follow_request_sent': None,
#    'followers_count': 527,
#    'following': None,
#    'friends_count': 202,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 814264798158405632,
#    'id_str': '814264798158405632',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Progress',
#    'name': 'maddy',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/814264798158405632/1488401013',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838493463914086402/xh2WnnFD_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838493463914086402/xh2WnnFD_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'msannyy',
#    'statuses_count': 956,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:28 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 18], 'text': 'IfIWereWireTapped'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741321372286976,
#   'id_str': '838741321372286976',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "#IfIWereWireTapped They'd hear fascinating stuff like: Do we need milk? &amp; Mom, we're done, pick me up &amp; I'd like a spring roll with that",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Mar 28 23:38:33 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'So now what?',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'periwinkle-paisley.blogspot.com',
#        'expanded_url': 'http://www.periwinkle-paisley.blogspot.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/ZO2g3XZ0cv'}]}},
#    'favourites_count': 408,
#    'follow_request_sent': None,
#    'followers_count': 451,
#    'following': None,
#    'friends_count': 633,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 27334938,
#    'id_str': '27334938',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 37,
#    'location': 'York, Pa',
#    'name': 'PeriwinklePaisley',
#    'notifications': None,
#    'profile_background_color': 'DBE9ED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/491228920180527104/-BcdrEzC.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/491228920180527104/-BcdrEzC.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27334938/1481978533',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/793891342321651712/MkHuncxh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/793891342321651712/MkHuncxh_normal.jpg',
#    'profile_link_color': 'CC3366',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JAddottaArtist',
#    'statuses_count': 1578,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ZO2g3XZ0cv',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:26 +0000 2017',
#   'entities': {'hashtags': [{'indices': [119, 134], 'text': 'getacttogether'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 15584149,
#      'id_str': '15584149',
#      'indices': [0, 13],
#      'name': 'ByJohnLMicek',
#      'screen_name': 'ByJohnLMicek'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741313755430912,
#   'id_str': '838741313755430912',
#   'in_reply_to_screen_name': 'ByJohnLMicek',
#   'in_reply_to_status_id': 838739855395983360,
#   'in_reply_to_status_id_str': '838739855395983360',
#   'in_reply_to_user_id': 15584149,
#   'in_reply_to_user_id_str': '15584149',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'text': "@ByJohnLMicek 85% of district is D. That's ripe for a write-in campaign that could actually still put a D in the seat. #getacttogether",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Dec 09 17:10:53 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Pop culture & Disney nerd, husband to @Orangela82; dad to @DogNamedPearl and Exec Director for @RepDanFrankel, and administrator of @disdownlow',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'disdownlow.com',
#        'expanded_url': 'http://www.disdownlow.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/giw4yPSuA3'}]}},
#    'favourites_count': 1218,
#    'follow_request_sent': None,
#    'followers_count': 287,
#    'following': None,
#    'friends_count': 420,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 17995836,
#    'id_str': '17995836',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 12,
#    'location': 'Harrisburg, PA',
#    'name': 'Gabe Spece',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17995836/1485661945',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/825553812874199042/uOl_N_3s_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/825553812874199042/uOl_N_3s_normal.jpg',
#    'profile_link_color': '91D2FA',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'gspece',
#    'statuses_count': 3652,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
#    'url': 'https://t.co/giw4yPSuA3',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:10 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1969002320,
#      'id_str': '1969002320',
#      'indices': [0, 11],
#      'name': 'Sniffen & Spellman',
#      'screen_name': 'Sniffenlaw'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741243437977600,
#   'id_str': '838741243437977600',
#   'in_reply_to_screen_name': 'TGAInsurance',
#   'in_reply_to_status_id': 837105184409010176,
#   'in_reply_to_status_id_str': '837105184409010176',
#   'in_reply_to_user_id': 91405231,
#   'in_reply_to_user_id_str': '91405231',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'text': '@Sniffenlaw Thanks for the RT!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Nov 20 19:14:55 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Part of South Central / #YorkPA for 65+ years helping you choose the best personal & business insurance. Proud #iloveyorkcity supporters!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'tga-ins.com',
#        'expanded_url': 'http://www.tga-ins.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/14gyRn66UL'}]}},
#    'favourites_count': 60,
#    'follow_request_sent': None,
#    'followers_count': 543,
#    'following': None,
#    'friends_count': 510,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 91405231,
#    'id_str': '91405231',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 22,
#    'location': 'York, PA',
#    'name': 'Glatfelter Agency',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/862574951/b3941bec27881d4897325b9559a7a124.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/862574951/b3941bec27881d4897325b9559a7a124.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/91405231/1485965850',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/935120449/TGAlogoBlueGrayfb_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/935120449/TGAlogoBlueGrayfb_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TGAInsurance',
#    'statuses_count': 3726,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
#    'url': 'http://t.co/14gyRn66UL',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:05 +0000 2017',
#   'entities': {'hashtags': [{'indices': [27, 31], 'text': 'TNM'},
#     {'indices': [80, 85], 'text': 'ouat'},
#     {'indices': [86, 90], 'text': 'snl'}],
#    'symbols': [],
#    'urls': [{'display_url': 'paper.li/TFBTWEETDJ/134…',
#      'expanded_url': 'http://paper.li/TFBTWEETDJ/1342941573?edition_id=71a391e0-026f-11e7-a350-0cc47a0d164b',
#      'indices': [56, 79],
#      'url': 'https://t.co/x6OurSeb1m'}],
#    'user_mentions': [{'id': 544524513,
#      'id_str': '544524513',
#      'indices': [3, 14],
#      'name': 'TweetDjRayne',
#      'screen_name': 'TFBTWEETDJ'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741225268211712,
#   'id_str': '838741225268211712',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 13:18:55 +0000 2017',
#    'entities': {'hashtags': [{'indices': [11, 15], 'text': 'TNM'},
#      {'indices': [64, 69], 'text': 'ouat'},
#      {'indices': [70, 74], 'text': 'snl'}],
#     'symbols': [],
#     'urls': [{'display_url': 'paper.li/TFBTWEETDJ/134…',
#       'expanded_url': 'http://paper.li/TFBTWEETDJ/1342941573?edition_id=71a391e0-026f-11e7-a350-0cc47a0d164b',
#       'indices': [40, 63],
#       'url': 'https://t.co/x6OurSeb1m'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 838740677278199810,
#    'id_str': '838740677278199810',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://paper.li" rel="nofollow">Paper.li</a>',
#    'text': 'The latest #TNM The New Music Movement! https://t.co/x6OurSeb1m #ouat #snl',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Apr 03 17:18:05 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '#LadyDjRayne #Dj #ShoutOut EXPLICIT Account! \r\nI Love #TEAMFOLLOWBACK I created #TEAMFANBACK  #TNM #MusicFam & the #LOVE2U tags! Tag it!  http://t.co/nO226mMIdt',
#     'entities': {'description': {'urls': [{'display_url': 'tnmwordup.com',
#         'expanded_url': 'http://www.tnmwordup.com',
#         'indices': [138, 160],
#         'url': 'http://t.co/nO226mMIdt'}]},
#      'url': {'urls': [{'display_url': 'TheNewMovement.com',
#         'expanded_url': 'http://www.TheNewMovement.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/raOsOxTp9Y'}]}},
#     'favourites_count': 1282,
#     'follow_request_sent': None,
#     'followers_count': 2978,
#     'following': None,
#     'friends_count': 2047,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 544524513,
#     'id_str': '544524513',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 78,
#     'location': 'Harrisburg PA ',
#     'name': 'TweetDjRayne',
#     'notifications': None,
#     'profile_background_color': '188894',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/456996245685272577/89z4ZmJ-.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/456996245685272577/89z4ZmJ-.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/544524513/1397791216',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3692690704/8fbbe4ef7dc43be479192f9a7f26ebc5_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3692690704/8fbbe4ef7dc43be479192f9a7f26ebc5_normal.jpeg',
#     'profile_link_color': 'B812AD',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'ECC493',
#     'profile_text_color': 'A34735',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'TFBTWEETDJ',
#     'statuses_count': 191358,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/raOsOxTp9Y',
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="https://roundteam.co" rel="nofollow">RoundTeam</a>',
#   'text': 'RT @TFBTWEETDJ: The latest #TNM The New Music Movement! https://t.co/x6OurSeb1m #ouat #snl',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jun 18 07:44:46 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#TNM #LadyRayne Tweets out MORE #music LINKS Less Twitchat #HOME OF #TNM  #MusicFAM #NONPROFIT   PROTECTING ARTISTS SINCE 2011 https://t.co/OCFNqwfOfP',
#    'entities': {'description': {'urls': [{'display_url': 'thenewmovement.com',
#        'expanded_url': 'http://www.thenewmovement.com',
#        'indices': [127, 150],
#        'url': 'https://t.co/OCFNqwfOfP'}]},
#     'url': {'urls': [{'display_url': 'linkedin.com/in/thenewmovem…',
#        'expanded_url': 'https://www.linkedin.com/in/thenewmovement',
#        'indices': [0, 23],
#        'url': 'https://t.co/MkVjSpoBKK'}]}},
#    'favourites_count': 2874,
#    'follow_request_sent': None,
#    'followers_count': 4085,
#    'following': None,
#    'friends_count': 3789,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 611566791,
#    'id_str': '611566791',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 168,
#    'location': 'Harrisburg PA;Miami FL',
#    'name': '#TNM TheNewMovement',
#    'notifications': None,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000091987397/e5db436caf2703c2ad9c1a309748913e.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000091987397/e5db436caf2703c2ad9c1a309748913e.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/611566791/1398890567',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/461606295456346112/qDWu8-Iq_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/461606295456346112/qDWu8-Iq_normal.jpeg',
#    'profile_link_color': '1D6B7D',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '8A8A8A',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': '24_7_TNMRadio',
#    'statuses_count': 116281,
#    'time_zone': 'Atlantic Time (Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/MkVjSpoBKK',
#    'utc_offset': -14400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:21:03 +0000 2017',
#   'entities': {'hashtags': [{'indices': [91, 101], 'text': 'SkimmLife'}],
#    'symbols': [],
#    'urls': [{'display_url': 'theskimm.com/?r=81c74989',
#      'expanded_url': 'http://www.theskimm.com/?r=81c74989',
#      'indices': [102, 125],
#      'url': 'https://t.co/gXiZUun389'}],
#    'user_mentions': [{'id': 515034648,
#      'id_str': '515034648',
#      'indices': [130, 139],
#      'name': 'theSkimm',
#      'screen_name': 'theskimm'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838741216808284161,
#   'id_str': '838741216808284161',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'text': "One more person to subscribe so I can become a Skimm'bassador! Love Skimm! ❤All up in that #SkimmLife https://t.co/gXiZUun389 via @theSkimm",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Mar 23 00:10:44 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Lobbyist at Long Nyquist & Assoc., former staffer with PA Legislature.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 469,
#    'follow_request_sent': None,
#    'followers_count': 210,
#    'following': None,
#    'friends_count': 447,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 125489642,
#    'id_str': '125489642',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'Lebanon, PA',
#    'name': 'Amy',
#    'notifications': None,
#    'profile_background_color': 'FFF04D',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/697996559/13172cb5d9b0d41ed4bc2a26eb2cfc69.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/697996559/13172cb5d9b0d41ed4bc2a26eb2cfc69.jpeg',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/676501540824219649/c1Y3HAys_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/676501540824219649/c1Y3HAys_normal.jpg',
#    'profile_link_color': '0099CC',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F6FFD1',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'alonggop',
#    'statuses_count': 593,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 10
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes

# %%
df_tweets['location'].unique()

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_york = ['York, PA','York PA','York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_york, 'York, PA')

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
