# %% [markdown]
# # Big Data: Problem Set 3
#
# ### Danya Littlefield
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %%
# Input the search term you want to search on
search_term='' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[42.354046, -71.068202] # A point on the Boston Common
# Setup a search distance
distance='15mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=30


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:19:56 +0000 2017',
#   'entities': {'hashtags': [{'indices': [33, 37], 'text': 'PPC'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 244592512,
#      'id_str': '244592512',
#      'indices': [3, 16],
#      'name': 'Mark Irvine',
#      'screen_name': 'MarkIrvine89'},
#     {'id': 16419153,
#      'id_str': '16419153',
#      'indices': [86, 97],
#      'name': 'WordStream',
#      'screen_name': 'WordStream'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771133377822722,
#   'id_str': '838771133377822722',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 3,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 15:19:00 +0000 2017',
#    'entities': {'hashtags': [{'indices': [15, 19], 'text': 'PPC'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/838770899117555713',
#       'indices': [121, 144],
#       'url': 'https://t.co/xwM776K05I'}],
#     'user_mentions': [{'id': 16419153,
#       'id_str': '16419153',
#       'indices': [68, 79],
#       'name': 'WordStream',
#       'screen_name': 'WordStream'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 838770899117555713,
#    'id_str': '838770899117555713',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Still writting #PPC ads the same way you did in 2016? Join me &amp; @Wordstream this Weds to learn new tricks for 2017!… https://t.co/xwM776K05I',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Jan 29 17:28:56 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'I do all of the maths. @Wordstream Sr Data Scientist. BU Alum. Bad Reality TV Junkie. \nTweets are my own and my employers rarely ever would agree with them.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'wordstream.com/blog/mark-irvi…',
#         'expanded_url': 'http://www.wordstream.com/blog/mark-irvine',
#         'indices': [0, 23],
#         'url': 'https://t.co/GeS5QaddzZ'}]}},
#     'favourites_count': 2380,
#     'follow_request_sent': None,
#     'followers_count': 2843,
#     'following': None,
#     'friends_count': 745,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 244592512,
#     'id_str': '244592512',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 154,
#     'location': 'Boston, MA',
#     'name': 'Mark Irvine',
#     'notifications': None,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/244592512/1410192587',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/827556820650754048/-pamPpL-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827556820650754048/-pamPpL-_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MarkIrvine89',
#     'statuses_count': 2834,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/GeS5QaddzZ',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @MarkIrvine89: Still writting #PPC ads the same way you did in 2016? Join me &amp; @Wordstream this Weds to learn new tricks for 2017! https…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 10 20:05:04 +0000 2015',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'In a World where Social Media has taken over .. we highlight The Best that is around ! For advertising contact us via DM ! WEBSITE COMING SOON !',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'Alluneedtoknow.com',
#        'expanded_url': 'http://www.Alluneedtoknow.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/22kLuXJG2f'}]}},
#    'favourites_count': 856,
#    'follow_request_sent': None,
#    'followers_count': 258,
#    'following': None,
#    'friends_count': 251,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 3028727638,
#    'id_str': '3028727638',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 213,
#    'location': 'Worldwide',
#    'name': 'TheBestOfSocialMedia',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3028727638/1476448062',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/786906147366264832/eE8nzu8h_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/786906147366264832/eE8nzu8h_normal.jpg',
#    'profile_link_color': '9266CC',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'BestOfSMM',
#    'statuses_count': 1933,
#    'time_zone': 'Dublin',
#    'translator_type': 'none',
#    'url': 'https://t.co/22kLuXJG2f',
#    'utc_offset': 0,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:19:56 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771133344321536,
#   'id_str': '838771133344321536',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'You wanna hold a conversation? Nigga money talk',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Aug 22 14:40:01 +0000 2010',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'I can lead you to the promise land, roll some dope and take my hand',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'soundcloud.com/hasselg',
#        'expanded_url': 'https://soundcloud.com/hasselg',
#        'indices': [0, 23],
#        'url': 'https://t.co/K2Z5khWRpA'}]}},
#    'favourites_count': 3526,
#    'follow_request_sent': None,
#    'followers_count': 253,
#    'following': None,
#    'friends_count': 308,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 181568357,
#    'id_str': '181568357',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 5,
#    'location': 'Cambridge, MA',
#    'name': 'The Rican Mamba',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/181568357/1486355851',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/827563251936423936/tsAgjcxd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827563251936423936/tsAgjcxd_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'HasselGenius',
#    'statuses_count': 6519,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/K2Z5khWRpA',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:19:56 +0000 2017',
#   'entities': {'hashtags': [{'indices': [38, 57],
#      'text': 'JustCause4Eviction'},
#     {'indices': [58, 66], 'text': 'RBoston'},
#     {'indices': [67, 75], 'text': 'bospoli'}],
#    'media': [{'display_url': 'pic.twitter.com/AmMkDFH4mD',
#      'expanded_url': 'https://twitter.com/CPAJustice/status/838766526081732608/photo/1',
#      'id': 838766523401515008,
#      'id_str': '838766523401515008',
#      'indices': [76, 99],
#      'media_url': 'http://pbs.twimg.com/media/C6PltYTWMAAj-NK.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6PltYTWMAAj-NK.jpg',
#      'sizes': {'large': {'h': 768, 'resize': 'fit', 'w': 1024},
#       'medium': {'h': 768, 'resize': 'fit', 'w': 1024},
#       'small': {'h': 510, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838766526081732608,
#      'source_status_id_str': '838766526081732608',
#      'source_user_id': 124274129,
#      'source_user_id_str': '124274129',
#      'type': 'photo',
#      'url': 'https://t.co/AmMkDFH4mD'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 124274129,
#      'id_str': '124274129',
#      'indices': [3, 14],
#      'name': 'CPA Justice',
#      'screen_name': 'CPAJustice'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/AmMkDFH4mD',
#      'expanded_url': 'https://twitter.com/CPAJustice/status/838766526081732608/photo/1',
#      'id': 838766523401515008,
#      'id_str': '838766523401515008',
#      'indices': [76, 99],
#      'media_url': 'http://pbs.twimg.com/media/C6PltYTWMAAj-NK.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6PltYTWMAAj-NK.jpg',
#      'sizes': {'large': {'h': 768, 'resize': 'fit', 'w': 1024},
#       'medium': {'h': 768, 'resize': 'fit', 'w': 1024},
#       'small': {'h': 510, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838766526081732608,
#      'source_status_id_str': '838766526081732608',
#      'source_user_id': 124274129,
#      'source_user_id_str': '124274129',
#      'type': 'photo',
#      'url': 'https://t.co/AmMkDFH4mD'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771132815798272,
#   'id_str': '838771132815798272',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 6,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 15:01:38 +0000 2017',
#    'entities': {'hashtags': [{'indices': [22, 41],
#       'text': 'JustCause4Eviction'},
#      {'indices': [42, 50], 'text': 'RBoston'},
#      {'indices': [51, 59], 'text': 'bospoli'}],
#     'media': [{'display_url': 'pic.twitter.com/AmMkDFH4mD',
#       'expanded_url': 'https://twitter.com/CPAJustice/status/838766526081732608/photo/1',
#       'id': 838766523401515008,
#       'id_str': '838766523401515008',
#       'indices': [60, 83],
#       'media_url': 'http://pbs.twimg.com/media/C6PltYTWMAAj-NK.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PltYTWMAAj-NK.jpg',
#       'sizes': {'large': {'h': 768, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 768, 'resize': 'fit', 'w': 1024},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/AmMkDFH4mD'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/AmMkDFH4mD',
#       'expanded_url': 'https://twitter.com/CPAJustice/status/838766526081732608/photo/1',
#       'id': 838766523401515008,
#       'id_str': '838766523401515008',
#       'indices': [60, 83],
#       'media_url': 'http://pbs.twimg.com/media/C6PltYTWMAAj-NK.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PltYTWMAAj-NK.jpg',
#       'sizes': {'large': {'h': 768, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 768, 'resize': 'fit', 'w': 1024},
#        'small': {'h': 510, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/AmMkDFH4mD'}]},
#    'favorite_count': 3,
#    'favorited': False,
#    'geo': None,
#    'id': 838766526081732608,
#    'id_str': '838766526081732608',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 6,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'People showing up for #JustCause4Eviction #RBoston #bospoli https://t.co/AmMkDFH4mD',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Mar 18 21:22:36 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Chinese Progressive Association is a grassroots community organization working for equality and empowerment of the Chinese community in the Greater Boston area.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'cpaboston.org',
#         'expanded_url': 'http://cpaboston.org/',
#         'indices': [0, 22],
#         'url': 'http://t.co/qtO4TFPKYJ'}]}},
#     'favourites_count': 609,
#     'follow_request_sent': None,
#     'followers_count': 919,
#     'following': None,
#     'friends_count': 715,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 124274129,
#     'id_str': '124274129',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 54,
#     'location': 'Boston, MA',
#     'name': 'CPA Justice',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/839383000/4bc6ad874dc4dd7141df182d843779f3.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/839383000/4bc6ad874dc4dd7141df182d843779f3.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/124274129/1418743047',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3503852730/d39f90f10dd6f2c31ed8d7d45c9eaab5_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3503852730/d39f90f10dd6f2c31ed8d7d45c9eaab5_normal.jpeg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'CPAJustice',
#     'statuses_count': 1899,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/qtO4TFPKYJ',
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'text': 'RT @CPAJustice: People showing up for #JustCause4Eviction #RBoston #bospoli https://t.co/AmMkDFH4mD',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Sep 21 02:10:55 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'You are NOT ALLOWED to start a new Cold War without my permission.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'theleder.com',
#        'expanded_url': 'http://www.theleder.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/OqBSaDAn0e'}]}},
#    'favourites_count': 45,
#    'follow_request_sent': None,
#    'followers_count': 2337,
#    'following': None,
#    'friends_count': 1699,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 75934946,
#    'id_str': '75934946',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 264,
#    'location': 'Massachusetts, USA',
#    'name': '((( Sisyphus )))',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/776223358543355904/utWM8rty_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/776223358543355904/utWM8rty_normal.jpg',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'papicek',
#    'statuses_count': 213623,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/OqBSaDAn0e',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:19:56 +0000 2017',
#   'entities': {'hashtags': [{'indices': [65, 83],
#      'text': 'FantasyBasketball'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 296520276,
#      'id_str': '296520276',
#      'indices': [3, 14],
#      'name': 'DraftKings',
#      'screen_name': 'DraftKings'},
#     {'id': 609548724,
#      'id_str': '609548724',
#      'indices': [97, 110],
#      'name': 'Rudy Gobert',
#      'screen_name': 'rudygobert27'},
#     {'id': 42562446,
#      'id_str': '42562446',
#      'indices': [115, 130],
#      'name': 'Stephen Curry',
#      'screen_name': 'StephenCurry30'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771132702556160,
#   'id_str': '838771132702556160',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 2,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 15:19:30 +0000 2017',
#    'entities': {'hashtags': [{'indices': [49, 67],
#       'text': 'FantasyBasketball'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/838771025731014658',
#       'indices': [116, 139],
#       'url': 'https://t.co/6BYO0dzGqe'}],
#     'user_mentions': [{'id': 609548724,
#       'id_str': '609548724',
#       'indices': [81, 94],
#       'name': 'Rudy Gobert',
#       'screen_name': 'rudygobert27'},
#      {'id': 42562446,
#       'id_str': '42562446',
#       'indices': [99, 114],
#       'name': 'Stephen Curry',
#       'screen_name': 'StephenCurry30'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 838771025731014658,
#    'id_str': '838771025731014658',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 2,
#    'retweeted': False,
#    'source': '<a href="http://www.spredfast.com" rel="nofollow">Spredfast app</a>',
#    'text': "The Stifle Tower led the way for yesterday's top #FantasyBasketball scorers!\n\n1. @rudygobert27 \n2. @StephenCurry30… https://t.co/6BYO0dzGqe",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue May 10 22:40:09 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'DraftKings is changing the way people experience sports. Compete in 1-day contests and win! Game on. Make your moment. https://t.co/LKgLeqKqct',
#     'entities': {'description': {'urls': [{'display_url': 'DraftKings.com',
#         'expanded_url': 'http://www.DraftKings.com',
#         'indices': [119, 142],
#         'url': 'https://t.co/LKgLeqKqct'}]},
#      'url': {'urls': [{'display_url': 'draftkings.com',
#         'expanded_url': 'https://www.draftkings.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/FGJOqwG8kK'}]}},
#     'favourites_count': 9218,
#     'follow_request_sent': None,
#     'followers_count': 232121,
#     'following': None,
#     'friends_count': 1238,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 296520276,
#     'id_str': '296520276',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1415,
#     'location': 'Boston, MA',
#     'name': 'DraftKings',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/501700826184699904/RaYzIFLE.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/501700826184699904/RaYzIFLE.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/296520276/1475854491',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/634380059466448896/U8KslVxE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/634380059466448896/U8KslVxE_normal.jpg',
#     'profile_link_color': '005200',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'DraftKings',
#     'statuses_count': 54245,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'regular',
#     'url': 'https://t.co/FGJOqwG8kK',
#     'utc_offset': -18000,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "RT @DraftKings: The Stifle Tower led the way for yesterday's top #FantasyBasketball scorers!\n\n1. @rudygobert27 \n2. @StephenCurry30 \n3. @Ant…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Feb 06 18:02:17 +0000 2012',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "God fearing|RIPTurboTweetKOLO&Laz| I'm a diamond in the rough! Don't try to put me in the trick bag 8FiFTY|Heat|FSU|Dolphins|paypal-cashlanemoney@gmail.com",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'CASHLANE.MajorLeagueCashCow.com',
#        'expanded_url': 'http://CASHLANE.MajorLeagueCashCow.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/mImoLjnkIV'}]}},
#    'favourites_count': 2724,
#    'follow_request_sent': None,
#    'followers_count': 584,
#    'following': None,
#    'friends_count': 523,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 484973413,
#    'id_str': '484973413',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 9,
#    'location': 'Draft Kings',
#    'name': 'UGoneEatYoConeBread?',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/484973413/1363742491',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/835938802304704512/1QZPs6XK_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835938802304704512/1QZPs6XK_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'T_Ready1',
#    'statuses_count': 53498,
#    'time_zone': 'Central Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/mImoLjnkIV',
#    'utc_offset': -21600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:19:56 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'fastcasual.com/blogs/standing…',
#      'expanded_url': 'http://www.fastcasual.com/blogs/standing-out-in-2017-how-to-implement-4-fresh-marketing-tips/',
#      'indices': [107, 130],
#      'url': 'https://t.co/4Ga1jmrizA'}],
#    'user_mentions': [{'id': 2216847096,
#      'id_str': '2216847096',
#      'indices': [99, 106],
#      'name': 'HelloWorld',
#      'screen_name': 'HW_inc'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771132081766401,
#   'id_str': '838771132081766401',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '"Marketers should look for ways to integrate fresh experiences into mobile apps" -Meredith Hillman @HW_inc https://t.co/4Ga1jmrizA',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Sep 04 03:49:47 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Helping #Restaurant Brands Launch Award-Winning #MobilePayment and #Loyalty Apps @thelevelup. Food Connoisseur. Wanderlust. Coffee Addict. (My Views)',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'thelevelup.com/agency',
#        'expanded_url': 'https://www.thelevelup.com/agency',
#        'indices': [0, 23],
#        'url': 'https://t.co/TiwANzji1K'}]}},
#    'favourites_count': 867,
#    'follow_request_sent': None,
#    'followers_count': 524,
#    'following': None,
#    'friends_count': 2191,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 2789051730,
#    'id_str': '2789051730',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 39,
#    'location': 'Boston, MA',
#    'name': 'Shannon Murray',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2789051730/1429832633',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/606573653069819905/pUpgpQ9T_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/606573653069819905/pUpgpQ9T_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'smurray5135',
#    'statuses_count': 701,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/TiwANzji1K',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:19:55 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'youtu.be/0l51kjHTcIY?a',
#      'expanded_url': 'http://youtu.be/0l51kjHTcIY?a',
#      'indices': [80, 103],
#      'url': 'https://t.co/iPnwTUbkJz'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771130328580097,
#   'id_str': '838771130328580097',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.google.com/" rel="nofollow">Google</a>',
#   'text': "Dem's Dire Prediction - Senator Schumer: President Is In Trouble - Fox &amp;... https://t.co/iPnwTUbkJz",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Apr 10 12:51:49 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#mass #teaparty mission bring Courage, Honesty and Integrity back into government for the purpose of restoring USA to a Constitutional Republic as founded',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'massteaparty.org',
#        'expanded_url': 'http://massteaparty.org',
#        'indices': [0, 22],
#        'url': 'http://t.co/WBnlyQra6N'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 443,
#    'following': None,
#    'friends_count': 184,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 280005240,
#    'id_str': '280005240',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 49,
#    'location': 'Saugus Ma',
#    'name': 'Mass Tea Party',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/268372916/masslogo3-44.gif',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/268372916/masslogo3-44.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1385138770/masslogo3small_normal.gif',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1385138770/masslogo3small_normal.gif',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'massteaparty',
#    'statuses_count': 48626,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/WBnlyQra6N',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:19:55 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 41876478,
#      'id_str': '41876478',
#      'indices': [0, 10],
#      'name': 'the sound of alcohol',
#      'screen_name': 'Taikoshep'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771128709623808,
#   'id_str': '838771128709623808',
#   'in_reply_to_screen_name': 'Taikoshep',
#   'in_reply_to_status_id': 838768194928041984,
#   'in_reply_to_status_id_str': '838768194928041984',
#   'in_reply_to_user_id': 41876478,
#   'in_reply_to_user_id_str': '41876478',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '@Taikoshep Our shep bros need to be drunk idiots together someday',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Sep 10 13:24:27 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I'm Nexus/Gale/Basalt/Dew/Tobasco. 25. I ♡ Sports & Nature. Engineer. Fursuiter & Mascot. Staff for ANE & MFF. Madly in love with @smellystrobes",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'furaffinity.net/user/nexusfolf',
#        'expanded_url': 'http://www.furaffinity.net/user/nexusfolf',
#        'indices': [0, 23],
#        'url': 'https://t.co/u1nDbwdbhB'}]}},
#    'favourites_count': 19904,
#    'follow_request_sent': None,
#    'followers_count': 9427,
#    'following': None,
#    'friends_count': 1607,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 371238908,
#    'id_str': '371238908',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 43,
#    'location': 'Boston, MA',
#    'name': 'Gale Frostbane',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/681854971701280768/rsJ8b7mU.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/681854971701280768/rsJ8b7mU.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/371238908/1484067935',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/813733132004368384/hj9_VtaF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/813733132004368384/hj9_VtaF_normal.jpg',
#    'profile_link_color': 'BF1EC7',
#    'profile_sidebar_border_color': '0B4216',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '1BD611',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'NexusFolf',
#    'statuses_count': 29854,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/u1nDbwdbhB',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:19:55 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/USlfOu0rWr',
#      'expanded_url': 'https://twitter.com/iRelateWords/status/838757310193364992/photo/1',
#      'id': 838757300818993155,
#      'id_str': '838757300818993155',
#      'indices': [46, 69],
#      'media_url': 'http://pbs.twimg.com/media/C6PdUjgU4AMg8Sc.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6PdUjgU4AMg8Sc.jpg',
#      'sizes': {'large': {'h': 1998, 'resize': 'fit', 'w': 1242},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 746},
#       'small': {'h': 680, 'resize': 'fit', 'w': 423},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838757310193364992,
#      'source_status_id_str': '838757310193364992',
#      'source_user_id': 69080331,
#      'source_user_id_str': '69080331',
#      'type': 'photo',
#      'url': 'https://t.co/USlfOu0rWr'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 69080331,
#      'id_str': '69080331',
#      'indices': [3, 16],
#      'name': 'Fuck Feelings',
#      'screen_name': 'iRelateWords'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/USlfOu0rWr',
#      'expanded_url': 'https://twitter.com/iRelateWords/status/838757310193364992/photo/1',
#      'id': 838757300818993155,
#      'id_str': '838757300818993155',
#      'indices': [46, 69],
#      'media_url': 'http://pbs.twimg.com/media/C6PdUjgU4AMg8Sc.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6PdUjgU4AMg8Sc.jpg',
#      'sizes': {'large': {'h': 1998, 'resize': 'fit', 'w': 1242},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 746},
#       'small': {'h': 680, 'resize': 'fit', 'w': 423},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838757310193364992,
#      'source_status_id_str': '838757310193364992',
#      'source_user_id': 69080331,
#      'source_user_id_str': '69080331',
#      'type': 'photo',
#      'url': 'https://t.co/USlfOu0rWr'},
#     {'display_url': 'pic.twitter.com/USlfOu0rWr',
#      'expanded_url': 'https://twitter.com/iRelateWords/status/838757310193364992/photo/1',
#      'id': 838757300818976768,
#      'id_str': '838757300818976768',
#      'indices': [46, 69],
#      'media_url': 'http://pbs.twimg.com/media/C6PdUjgUoAAaKBL.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6PdUjgUoAAaKBL.jpg',
#      'sizes': {'large': {'h': 1136, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 1136, 'resize': 'fit', 'w': 640},
#       'small': {'h': 680, 'resize': 'fit', 'w': 383},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838757310193364992,
#      'source_status_id_str': '838757310193364992',
#      'source_user_id': 69080331,
#      'source_user_id_str': '69080331',
#      'type': 'photo',
#      'url': 'https://t.co/USlfOu0rWr'},
#     {'display_url': 'pic.twitter.com/USlfOu0rWr',
#      'expanded_url': 'https://twitter.com/iRelateWords/status/838757310193364992/photo/1',
#      'id': 838757300818976771,
#      'id_str': '838757300818976771',
#      'indices': [46, 69],
#      'media_url': 'http://pbs.twimg.com/media/C6PdUjgUoAMM-vR.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6PdUjgUoAMM-vR.jpg',
#      'sizes': {'large': {'h': 1136, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 1136, 'resize': 'fit', 'w': 640},
#       'small': {'h': 680, 'resize': 'fit', 'w': 383},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838757310193364992,
#      'source_status_id_str': '838757310193364992',
#      'source_user_id': 69080331,
#      'source_user_id_str': '69080331',
#      'type': 'photo',
#      'url': 'https://t.co/USlfOu0rWr'},
#     {'display_url': 'pic.twitter.com/USlfOu0rWr',
#      'expanded_url': 'https://twitter.com/iRelateWords/status/838757310193364992/photo/1',
#      'id': 838757300818960386,
#      'id_str': '838757300818960386',
#      'indices': [46, 69],
#      'media_url': 'http://pbs.twimg.com/media/C6PdUjgUYAIM6iT.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6PdUjgUYAIM6iT.jpg',
#      'sizes': {'large': {'h': 1136, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 1136, 'resize': 'fit', 'w': 640},
#       'small': {'h': 680, 'resize': 'fit', 'w': 383},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838757310193364992,
#      'source_status_id_str': '838757310193364992',
#      'source_user_id': 69080331,
#      'source_user_id_str': '69080331',
#      'type': 'photo',
#      'url': 'https://t.co/USlfOu0rWr'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771128705429505,
#   'id_str': '838771128705429505',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 143,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 14:25:00 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/USlfOu0rWr',
#       'expanded_url': 'https://twitter.com/iRelateWords/status/838757310193364992/photo/1',
#       'id': 838757300818993155,
#       'id_str': '838757300818993155',
#       'indices': [28, 51],
#       'media_url': 'http://pbs.twimg.com/media/C6PdUjgU4AMg8Sc.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PdUjgU4AMg8Sc.jpg',
#       'sizes': {'large': {'h': 1998, 'resize': 'fit', 'w': 1242},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 746},
#        'small': {'h': 680, 'resize': 'fit', 'w': 423},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/USlfOu0rWr'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/USlfOu0rWr',
#       'expanded_url': 'https://twitter.com/iRelateWords/status/838757310193364992/photo/1',
#       'id': 838757300818993155,
#       'id_str': '838757300818993155',
#       'indices': [28, 51],
#       'media_url': 'http://pbs.twimg.com/media/C6PdUjgU4AMg8Sc.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PdUjgU4AMg8Sc.jpg',
#       'sizes': {'large': {'h': 1998, 'resize': 'fit', 'w': 1242},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 746},
#        'small': {'h': 680, 'resize': 'fit', 'w': 423},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/USlfOu0rWr'},
#      {'display_url': 'pic.twitter.com/USlfOu0rWr',
#       'expanded_url': 'https://twitter.com/iRelateWords/status/838757310193364992/photo/1',
#       'id': 838757300818976768,
#       'id_str': '838757300818976768',
#       'indices': [28, 51],
#       'media_url': 'http://pbs.twimg.com/media/C6PdUjgUoAAaKBL.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PdUjgUoAAaKBL.jpg',
#       'sizes': {'large': {'h': 1136, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 1136, 'resize': 'fit', 'w': 640},
#        'small': {'h': 680, 'resize': 'fit', 'w': 383},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/USlfOu0rWr'},
#      {'display_url': 'pic.twitter.com/USlfOu0rWr',
#       'expanded_url': 'https://twitter.com/iRelateWords/status/838757310193364992/photo/1',
#       'id': 838757300818976771,
#       'id_str': '838757300818976771',
#       'indices': [28, 51],
#       'media_url': 'http://pbs.twimg.com/media/C6PdUjgUoAMM-vR.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PdUjgUoAMM-vR.jpg',
#       'sizes': {'large': {'h': 1136, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 1136, 'resize': 'fit', 'w': 640},
#        'small': {'h': 680, 'resize': 'fit', 'w': 383},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/USlfOu0rWr'},
#      {'display_url': 'pic.twitter.com/USlfOu0rWr',
#       'expanded_url': 'https://twitter.com/iRelateWords/status/838757310193364992/photo/1',
#       'id': 838757300818960386,
#       'id_str': '838757300818960386',
#       'indices': [28, 51],
#       'media_url': 'http://pbs.twimg.com/media/C6PdUjgUYAIM6iT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PdUjgUYAIM6iT.jpg',
#       'sizes': {'large': {'h': 1136, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 1136, 'resize': 'fit', 'w': 640},
#        'small': {'h': 680, 'resize': 'fit', 'w': 383},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/USlfOu0rWr'}]},
#    'favorite_count': 361,
#    'favorited': False,
#    'geo': None,
#    'id': 838757310193364992,
#    'id_str': '838757310193364992',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 143,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'tinder is something else 😂😂 https://t.co/USlfOu0rWr',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Aug 26 20:05:50 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "I'm just tweeting what i want, my feelings & my thoughts. Hoping to inspire each and everyone of you. BTW. Don't like me? I don't give a FUCK!",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'irelatewords.tumblr.com',
#         'expanded_url': 'http://irelatewords.tumblr.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/79UtKKJMSH'}]}},
#     'favourites_count': 7276,
#     'follow_request_sent': None,
#     'followers_count': 1229989,
#     'following': None,
#     'friends_count': 695094,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 69080331,
#     'id_str': '69080331',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1345,
#     'location': 'Boston, MA ',
#     'name': 'Fuck Feelings',
#     'notifications': None,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000160601363/vNmYGm1T.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000160601363/vNmYGm1T.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/69080331/1488785216',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/838651116590071810/UvBYpfJs_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838651116590071810/UvBYpfJs_normal.jpg',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'iRelateWords',
#     'statuses_count': 48927,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/79UtKKJMSH',
#     'utc_offset': -21600,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @iRelateWords: tinder is something else 😂😂 https://t.co/USlfOu0rWr',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri May 10 02:56:42 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Snapchat: charlieabernath , Lou 6/1/14 we love you brother . I swear im calebs dad. Also a verified infidel. -US Marine-',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3582,
#    'follow_request_sent': None,
#    'followers_count': 469,
#    'following': None,
#    'friends_count': 749,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1416997410,
#    'id_str': '1416997410',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'Atlanta, GA',
#    'name': 'Abernasty',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
# ...
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838324495895113728/BcbozH1t_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'buss_jan',
#    'statuses_count': 501,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:19:51 +0000 2017',
#   'entities': {'hashtags': [{'indices': [91, 97], 'text': 'Trump'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 28279637,
#      'id_str': '28279637',
#      'indices': [3, 11],
#      'name': 'David Beard',
#      'screen_name': 'dabeard'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771113467523072,
#   'id_str': '838771113467523072',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1892,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 01:10:33 +0000 2017',
#    'entities': {'hashtags': [{'indices': [78, 84], 'text': 'Trump'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/838557377192394752',
#       'indices': [113, 136],
#       'url': 'https://t.co/iizbsFEtgD'}],
#     'user_mentions': []},
#    'favorite_count': 1194,
#    'favorited': False,
#    'geo': None,
#    'id': 838557377192394752,
#    'id_str': '838557377192394752',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1892,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': '2 tours of duty in Afghanistan. Sustained a brain injury in an explosion. Now #Trump admin wants to deport him.… https://t.co/iizbsFEtgD',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Apr 02 04:14:41 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Finding great audiences for great storytelling, currently helping @AP and @statnews Priors: @WashingtonPost @PRI @BostonGlobe beardwrites@gmail.com',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'linkedin.com/in/dabeard1',
#         'expanded_url': 'https://www.linkedin.com/in/dabeard1',
#         'indices': [0, 23],
#         'url': 'https://t.co/GWxL0YFFy8'}]}},
#     'favourites_count': 37528,
#     'follow_request_sent': None,
#     'followers_count': 27129,
#     'following': None,
#     'friends_count': 4696,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 28279637,
#     'id_str': '28279637',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1496,
#     'location': 'Boston',
#     'name': 'David Beard',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/28279637/1488655805',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3773956722/060a643d3de230a1dc983716fb91125f_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3773956722/060a643d3de230a1dc983716fb91125f_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'dabeard',
#     'statuses_count': 49331,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/GWxL0YFFy8',
#     'utc_offset': -18000,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @dabeard: 2 tours of duty in Afghanistan. Sustained a brain injury in an explosion. Now #Trump admin wants to deport him. https://t.co/0…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Apr 14 20:33:46 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 32486,
#    'follow_request_sent': None,
#    'followers_count': 641,
#    'following': None,
#    'friends_count': 700,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 720711668087529472,
#    'id_str': '720711668087529472',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 80,
#    'location': 'Fruit Cove, FL',
#    'name': '#BernieOrBust',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/720711668087529472/1486564486',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/730867505531621376/HLlH-6dW_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/730867505531621376/HLlH-6dW_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'DeborahSharp20',
#    'statuses_count': 15174,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:19:51 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2456021262,
#      'id_str': '2456021262',
#      'indices': [3, 18],
#      'name': 'Ben SDMF \\m/',
#      'screen_name': 'metal_humanism'},
#     {'id': 3092894686,
#      'id_str': '3092894686',
#      'indices': [33, 46],
#      'name': 'Deniz',
#      'screen_name': 'denizzemreee'},
#     {'id': 2438449390,
#      'id_str': '2438449390',
#      'indices': [47, 63],
#      'name': 'Tracy 💕',
#      'screen_name': 'vixentink_tracy'},
#     {'id': 2616635620,
#      'id_str': '2616635620',
#      'indices': [64, 74],
#      'name': 'Shiva',
#      'screen_name': 'taherehch'},
#     {'id': 753378199,
#      'id_str': '753378199',
#      'indices': [75, 85],
#      'name': 'E',
#      'screen_name': 'Xavgenper'},
#     {'id': 2725692935,
#      'id_str': '2725692935',
#      'indices': [86, 93],
#      'name': 'Lofn Lake',
#      'screen_name': 'lofn_6'},
#     {'id': 1534987213,
#      'id_str': '1534987213',
#      'indices': [94, 107],
#      'name': '🤘 G 🤘',
#      'screen_name': 'slayerific13'},
#     {'id': 2474339160,
#      'id_str': '2474339160',
#      'indices': [108, 117],
#      'name': 'Vampiria',
#      'screen_name': 'Vampiria'},
#     {'id': 3495045376,
#      'id_str': '3495045376',
#      'indices': [118, 131],
#      'name': 'Shay',
#      'screen_name': 'Clover_Mouse'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771112737660928,
#   'id_str': '838771112737660928',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'in',
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 4,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 12:54:59 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/rPcwDy0m9E',
#       'expanded_url': 'https://twitter.com/metal_humanism/status/838372267830673408/photo/1',
#       'id': 838372261996408832,
#       'id_str': '838372261996408832',
#       'indices': [112, 135],
#       'media_url': 'http://pbs.twimg.com/media/C6J_IWHWMAAft6F.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6J_IWHWMAAft6F.jpg',
#       'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 407},
#        'medium': {'h': 399, 'resize': 'fit', 'w': 407},
#        'small': {'h': 399, 'resize': 'fit', 'w': 407},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/rPcwDy0m9E'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3092894686,
#       'id_str': '3092894686',
#       'indices': [13, 26],
#       'name': 'Deniz',
#       'screen_name': 'denizzemreee'},
#      {'id': 2438449390,
#       'id_str': '2438449390',
#       'indices': [27, 43],
#       'name': 'Tracy 💕',
#       'screen_name': 'vixentink_tracy'},
#      {'id': 2616635620,
#       'id_str': '2616635620',
#       'indices': [44, 54],
#       'name': 'Shiva',
#       'screen_name': 'taherehch'},
#      {'id': 753378199,
#       'id_str': '753378199',
#       'indices': [55, 65],
#       'name': 'E',
#       'screen_name': 'Xavgenper'},
#      {'id': 2725692935,
#       'id_str': '2725692935',
#       'indices': [66, 73],
#       'name': 'Lofn Lake',
#       'screen_name': 'lofn_6'},
#      {'id': 1534987213,
#       'id_str': '1534987213',
#       'indices': [74, 87],
#       'name': '🤘 G 🤘',
#       'screen_name': 'slayerific13'},
#      {'id': 2474339160,
#       'id_str': '2474339160',
#       'indices': [88, 97],
#       'name': 'Vampiria',
#       'screen_name': 'Vampiria'},
#      {'id': 3495045376,
#       'id_str': '3495045376',
#       'indices': [98, 111],
#       'name': 'Shay',
#       'screen_name': 'Clover_Mouse'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/rPcwDy0m9E',
#       'expanded_url': 'https://twitter.com/metal_humanism/status/838372267830673408/photo/1',
#       'id': 838372261996408832,
#       'id_str': '838372261996408832',
#       'indices': [112, 135],
#       'media_url': 'http://pbs.twimg.com/media/C6J_IWHWMAAft6F.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6J_IWHWMAAft6F.jpg',
#       'sizes': {'large': {'h': 399, 'resize': 'fit', 'w': 407},
#        'medium': {'h': 399, 'resize': 'fit', 'w': 407},
#        'small': {'h': 399, 'resize': 'fit', 'w': 407},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/rPcwDy0m9E'}]},
#    'favorite_count': 10,
#    'favorited': False,
#    'geo': None,
#    'id': 838372267830673408,
#    'id_str': '838372267830673408',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'in',
#    'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Persian rug😊 @denizzemreee @vixentink_tracy @taherehch @Xavgenper @lofn_6 @slayerific13 @Vampiria @Clover_Mouse https://t.co/rPcwDy0m9E',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Apr 21 05:31:11 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Epic imagery, heavy metal, fantasy, nature and loves photography art and cooking. Hard worker, easy going. I am a Renaissance man.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'curry.edu',
#         'expanded_url': 'http://www.curry.edu/',
#         'indices': [0, 23],
#         'url': 'https://t.co/3XGBbdJrlw'}]}},
#     'favourites_count': 60991,
#     'follow_request_sent': None,
#     'followers_count': 4574,
#     'following': None,
#     'friends_count': 4235,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 2456021262,
#     'id_str': '2456021262',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 76,
#     'location': 'Boston, MA',
#     'name': 'Ben SDMF \\m/',
#     'notifications': None,
#     'profile_background_color': '1D20ED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/461203199618072576/UAZSi8bH.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/461203199618072576/UAZSi8bH.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2456021262/1481639030',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/832604762667438080/iS0mnU1R_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/832604762667438080/iS0mnU1R_normal.jpg',
#     'profile_link_color': '20C3D9',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'metal_humanism',
#     'statuses_count': 41739,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/3XGBbdJrlw',
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @metal_humanism: Persian rug😊 @denizzemreee @vixentink_tracy @taherehch @Xavgenper @lofn_6 @slayerific13 @Vampiria @Clover_Mouse https:/…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Aug 12 16:20:21 +0000 2012',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Norse/Asatru, huge Vikings (TV) fan,Travis Fimmel, Tom Hardy, NO racists, 18+  DM by invite only',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 160053,
#    'follow_request_sent': None,
#    'followers_count': 3655,
#    'following': None,
#    'friends_count': 1292,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 753378199,
#    'id_str': '753378199',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 202,
#    'location': '',
#    'name': 'E',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/753378199/1396228844',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/698598907547381760/h1qqc0F2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/698598907547381760/h1qqc0F2_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Xavgenper',
#    'statuses_count': 144762,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}}]
