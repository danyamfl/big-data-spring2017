# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[40.261455,-76.882553] # Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:15:26 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/foxandfriends/…',
#      'expanded_url': 'https://twitter.com/foxandfriends/status/839805482889945090',
#      'indices': [92, 115],
#      'url': 'https://t.co/DkQqRi1XWb'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811867052736512,
#   'id_str': '839811867052736512',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 09 11:50:04 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/8gW1Vtl3fA',
#       'expanded_url': 'https://twitter.com/foxandfriends/status/839805482889945090/video/1',
#       'id': 839802664359620608,
#       'id_str': '839802664359620608',
#       'indices': [110, 133],
#       'media_url': 'http://pbs.twimg.com/media/C6eUVK2VQAASEZ4.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6eUVK2VQAASEZ4.jpg',
#       'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 360, 'resize': 'fit', 'w': 640},
#        'small': {'h': 360, 'resize': 'fit', 'w': 640},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/8gW1Vtl3fA'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 488679352,
#       'id_str': '488679352',
#       'indices': [92, 108],
#       'name': 'Fox & Friends First',
#       'screen_name': 'FoxFriendsFirst'}]},
#    'extended_entities': {'media': [{'additional_media_info': {'description': '',
#        'embeddable': False,
#        'monetizable': False,
#        'title': ''},
#       'display_url': 'pic.twitter.com/8gW1Vtl3fA',
#       'expanded_url': 'https://twitter.com/foxandfriends/status/839805482889945090/video/1',
#       'id': 839802664359620608,
#       'id_str': '839802664359620608',
#       'indices': [110, 133],
#       'media_url': 'http://pbs.twimg.com/media/C6eUVK2VQAASEZ4.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6eUVK2VQAASEZ4.jpg',
#       'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 360, 'resize': 'fit', 'w': 640},
#        'small': {'h': 360, 'resize': 'fit', 'w': 640},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'video',
#       'url': 'https://t.co/8gW1Vtl3fA',
#       'video_info': {'aspect_ratio': [427, 240],
#        'duration_millis': 40073,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/839802664359620608/vid/640x360/xTO5ciZoZ_zn_xBs.mp4'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/amplify_video/839802664359620608/pl/u7GjX9EQ-50heYKZ.m3u8'},
#         {'bitrate': 320000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/839802664359620608/vid/320x180/Qnit8SfFjK0xAEoe.mp4'},
#         {'content_type': 'application/dash+xml',
#          'url': 'https://video.twimg.com/amplify_video/839802664359620608/pl/u7GjX9EQ-50heYKZ.mpd'}]}}]},
#    'favorite_count': 143,
#    'favorited': False,
#    'geo': None,
#    'id': 839805482889945090,
#    'id_str': '839805482889945090',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 76,
#    'retweeted': False,
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>',
#    'text': 'Democratic Vermont mayor claims his Syrian refugee plan cost him from being re-elected (via @FoxFriendsFirst) https://t.co/8gW1Vtl3fA',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jul 21 10:50:09 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "America's #1 cable morning news show",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'foxandfriends.com',
#         'expanded_url': 'http://foxandfriends.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/xg790NQUNl'}]}},
#     'favourites_count': 4947,
#     'follow_request_sent': None,
#     'followers_count': 818868,
#     'following': None,
#     'friends_count': 2726,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 15513604,
#     'id_str': '15513604',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 6780,
#     'location': 'New York City',
#     'name': 'FOX & friends',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000073438215/a640e235e8df7d23d551f500af24d6b8.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000073438215/a640e235e8df7d23d551f500af24d6b8.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15513604/1456513601',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/816026255963340800/6SZPq7zi_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/816026255963340800/6SZPq7zi_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'foxandfriends',
#     'statuses_count': 61242,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/xg790NQUNl',
#     'utc_offset': -18000,
#     'verified': True}},
#   'quoted_status_id': 839805482889945090,
#   'quoted_status_id_str': '839805482889945090',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'text': "It's time these representatives listen to their constituents..it is their job.. who is next https://t.co/DkQqRi1XWb",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jan 21 13:05:53 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Average all American woman 49 Mother of 1 female 1 male 3 dogs married pro choice atheist republican 1/2 Puerto Rican 1/2 Irish',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 2033,
#    'follow_request_sent': None,
#    'followers_count': 105,
#    'following': None,
#    'friends_count': 177,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 822792330289745920,
#    'id_str': '822792330289745920',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 7,
#    'location': 'Camp Hill, PA',
#    'name': 'Angela allander',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/822880462121136128/dUV1CtzP_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822880462121136128/dUV1CtzP_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'AngelaAllander',
#    'statuses_count': 5487,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:15:26 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 129760791,
#      'id_str': '129760791',
#      'indices': [0, 10],
#      'name': 'صاحب الظل الطويل',
#      'screen_name': 'fish_fash'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811864863391745,
#   'id_str': '839811864863391745',
#   'in_reply_to_screen_name': 'fish_fash',
#   'in_reply_to_status_id': 839811614052335617,
#   'in_reply_to_status_id_str': '839811614052335617',
#   'in_reply_to_user_id': 129760791,
#   'in_reply_to_user_id_str': '129760791',
#   'is_quote_status': False,
#   'lang': 'ar',
#   'metadata': {'iso_language_code': 'ar', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@fish_fash شفت لما ضحك ابوهم تكلمو 😩❤️',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Aug 03 19:34:30 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'ضاعو اللي جو معاها مسيرات .',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'Shooqa1.Sarahah.com',
#        'expanded_url': 'https://Shooqa1.Sarahah.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/Ftr85eJwOR'}]}},
#    'favourites_count': 887,
#    'follow_request_sent': None,
#    'followers_count': 990,
#    'following': None,
#    'friends_count': 336,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 2704735884,
#    'id_str': '2704735884',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ar',
#    'listed_count': 3,
#    'location': 'Lebanon, PA',
#    'name': 'شوق 🌧',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2704735884/1488880403',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838472660334039041/M6wyzMOp_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838472660334039041/M6wyzMOp_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Shooqksa1',
#    'statuses_count': 24588,
#    'time_zone': 'Nairobi',
#    'translator_type': 'none',
#    'url': 'https://t.co/Ftr85eJwOR',
#    'utc_offset': 10800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:15:22 +0000 2017',
#   'entities': {'hashtags': [{'indices': [23, 31], 'text': 'infosec'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811847691907072,
#   'id_str': '839811847691907072',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'text': "Today is the day! It's #infosec Thursday...are you secure?",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Oct 27 14:53:42 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Food Enthusiast. Infuriatingly Humble Introvert. Unapologetic Lifelong Problem Solver. Subtly Charming Entrepreneur. Freelance Beer Geek. Computer Evangelist',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'virtualoctober.com',
#        'expanded_url': 'http://www.virtualoctober.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/Efmh9JY8sa'}]}},
#    'favourites_count': 111,
#    'follow_request_sent': None,
#    'followers_count': 534,
#    'following': None,
#    'friends_count': 683,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 16999686,
#    'id_str': '16999686',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 88,
#    'location': 'York, PA',
#    'name': 'Alan Feldman',
#    'notifications': None,
#    'profile_background_color': '022330',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16999686/1457628857',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/612968300797104128/ZfOUfiTA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/612968300797104128/ZfOUfiTA_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'afvoct',
#    'statuses_count': 2978,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/Efmh9JY8sa',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:15:04 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811772563484672,
#   'id_str': '839811772563484672',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'text': '"707 good morning Wendy!" "Good morning, Dee."',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Aug 01 15:37:35 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Good Morning.\n#NYCSDstory, I guess.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1,
#    'follow_request_sent': None,
#    'followers_count': 6,
#    'following': None,
#    'friends_count': 3,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 3398906584,
#    'id_str': '3398906584',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Dillsburg, PA',
#    'name': 'Wendy Dee',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3398906584/1438444377',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/627505805059878912/oNcC8wnO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/627505805059878912/oNcC8wnO_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': '707_wendee',
#    'statuses_count': 585,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:15:01 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'local21news.com/news/local/fac…',
#      'expanded_url': 'http://local21news.com/news/local/face-with-serious-financial-struggles-duncannon-borough-considering-merger',
#      'indices': [78, 101],
#      'url': 'https://t.co/RFiULpfswt'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811760030900224,
#   'id_str': '839811760030900224',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'text': 'Faced with serious financial struggles, Duncannon Borough considering merger\n\nhttps://t.co/RFiULpfswt',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Oct 24 12:18:54 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Your station for news, sports and weather in Central Pennsylvania.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'local21news.com',
#        'expanded_url': 'http://www.local21news.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/GeDcKVs5WO'}]}},
#    'favourites_count': 810,
#    'follow_request_sent': None,
#    'followers_count': 49686,
#    'following': None,
#    'friends_count': 878,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 9651842,
#    'id_str': '9651842',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 671,
#    'location': 'Harrisburg, Pennsylvania, USA',
#    'name': 'CBS 21 News',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000042559743/47b0f49752af8cb84140a3097bf0e164.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000042559743/47b0f49752af8cb84140a3097bf0e164.jpeg',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/758887448059359232/KG3gj6Md_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/758887448059359232/KG3gj6Md_normal.jpg',
#    'profile_link_color': 'E60003',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'E8E8E8',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'CBS21NEWS',
#    'statuses_count': 148885,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/GeDcKVs5WO',
#    'utc_offset': -18000,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:15:00 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811757447266304,
#   'id_str': '839811757447266304',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ar',
#   'metadata': {'iso_language_code': 'ar', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'جلسة البيت تجيب الهم ابكم خيميس',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Aug 03 19:34:30 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'ضاعو اللي جو معاها مسيرات .',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'Shooqa1.Sarahah.com',
#        'expanded_url': 'https://Shooqa1.Sarahah.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/Ftr85eJwOR'}]}},
#    'favourites_count': 887,
#    'follow_request_sent': None,
#    'followers_count': 990,
#    'following': None,
#    'friends_count': 336,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 2704735884,
#    'id_str': '2704735884',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ar',
#    'listed_count': 3,
#    'location': 'Lebanon, PA',
#    'name': 'شوق 🌧',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2704735884/1488880403',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838472660334039041/M6wyzMOp_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838472660334039041/M6wyzMOp_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Shooqksa1',
#    'statuses_count': 24588,
#    'time_zone': 'Nairobi',
#    'translator_type': 'none',
#    'url': 'https://t.co/Ftr85eJwOR',
#    'utc_offset': 10800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:14:56 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 3], 'text': 'np'},
#     {'indices': [80, 87], 'text': 'hazefm'}],
#    'symbols': [],
#    'urls': [{'display_url': 'haze.FM',
#      'expanded_url': 'http://haze.FM',
#      'indices': [56, 79],
#      'url': 'https://t.co/7oChTkUywp'}],
#    'user_mentions': [{'id': 67982898,
#      'id_str': '67982898',
#      'indices': [4, 12],
#      'name': 'ASHANTI',
#      'screen_name': 'ashanti'},
#     {'id': 24278900,
#      'id_str': '24278900',
#      'indices': [40, 52],
#      'name': 'Busta Rhymes',
#      'screen_name': 'BustaRhymes'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811741697654784,
#   'id_str': '839811741697654784',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://share.radionomy.com" rel="nofollow">Share.Radionomy.com</a>',
#   'text': '#np @ashanti - The woman you love feat. @bustarhymes on https://t.co/7oChTkUywp #hazefm',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Sep 11 03:46:26 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Blazing Hip Hop & R&B Internet Radio Station playing Todays hottest hits and some from Yesterday. Download our Apps. https://t.co/eo3crFPSEh',
#    'entities': {'description': {'urls': [{'display_url': 'haze.fm/apps',
#        'expanded_url': 'http://haze.fm/apps',
#        'indices': [117, 140],
#        'url': 'https://t.co/eo3crFPSEh'}]},
#     'url': {'urls': [{'display_url': 'haze.fm',
#        'expanded_url': 'http://www.haze.fm',
#        'indices': [0, 23],
#        'url': 'https://t.co/zI6RsHepl0'}]}},
#    'favourites_count': 375,
#    'follow_request_sent': None,
#    'followers_count': 49561,
#    'following': None,
#    'friends_count': 755,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 73302162,
#    'id_str': '73302162',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 283,
#    'location': 'York, PA',
#    'name': 'HAZE.FM',
#    'notifications': None,
#    'profile_background_color': 'FFFAFA',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/628210922/b0urz7l6a1g9jktdaoye.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/628210922/b0urz7l6a1g9jktdaoye.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/73302162/1486148777',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/827594065701113856/Xq8Mto1I_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827594065701113856/Xq8Mto1I_normal.jpg',
#    'profile_link_color': '3E00FF',
#    'profile_sidebar_border_color': 'E9EDFE',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '680979',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'HazeFM',
#    'statuses_count': 260140,
#    'time_zone': 'Central Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/zI6RsHepl0',
#    'utc_offset': -21600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:14:46 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/Q3mFek73Jv',
#      'expanded_url': 'https://twitter.com/yagirlrocks/status/837707572715094020/photo/1',
#      'id': 837707566734061568,
#      'id_str': '837707566734061568',
#      'indices': [68, 91],
#      'media_url': 'http://pbs.twimg.com/media/C6Ail_TXMAAfVNc.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6Ail_TXMAAfVNc.jpg',
#      'sizes': {'large': {'h': 1632, 'resize': 'fit', 'w': 1224},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 900},
#       'small': {'h': 680, 'resize': 'fit', 'w': 510},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 837707572715094020,
#      'source_status_id_str': '837707572715094020',
#      'source_user_id': 767487035942854656,
#      'source_user_id_str': '767487035942854656',
#      'type': 'photo',
#      'url': 'https://t.co/Q3mFek73Jv'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 767487035942854656,
#      'id_str': '767487035942854656',
#      'indices': [3, 15],
#      'name': 'rocky☀️',
#      'screen_name': 'yagirlrocks'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Q3mFek73Jv',
#      'expanded_url': 'https://twitter.com/yagirlrocks/status/837707572715094020/photo/1',
#      'id': 837707566734061568,
#      'id_str': '837707566734061568',
#      'indices': [68, 91],
#      'media_url': 'http://pbs.twimg.com/media/C6Ail_TXMAAfVNc.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6Ail_TXMAAfVNc.jpg',
#      'sizes': {'large': {'h': 1632, 'resize': 'fit', 'w': 1224},
#       'medium': {'h': 1200, 'resize': 'fit', 'w': 900},
#       'small': {'h': 680, 'resize': 'fit', 'w': 510},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 837707572715094020,
#      'source_status_id_str': '837707572715094020',
#      'source_user_id': 767487035942854656,
#      'source_user_id_str': '767487035942854656',
#      'type': 'photo',
#      'url': 'https://t.co/Q3mFek73Jv'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811697284120576,
#   'id_str': '839811697284120576',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 374,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Mar 03 16:53:43 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/Q3mFek73Jv',
#       'expanded_url': 'https://twitter.com/yagirlrocks/status/837707572715094020/photo/1',
#       'id': 837707566734061568,
#       'id_str': '837707566734061568',
#       'indices': [51, 74],
#       'media_url': 'http://pbs.twimg.com/media/C6Ail_TXMAAfVNc.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6Ail_TXMAAfVNc.jpg',
#       'sizes': {'large': {'h': 1632, 'resize': 'fit', 'w': 1224},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 900},
#        'small': {'h': 680, 'resize': 'fit', 'w': 510},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/Q3mFek73Jv'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/Q3mFek73Jv',
#       'expanded_url': 'https://twitter.com/yagirlrocks/status/837707572715094020/photo/1',
#       'id': 837707566734061568,
#       'id_str': '837707566734061568',
#       'indices': [51, 74],
#       'media_url': 'http://pbs.twimg.com/media/C6Ail_TXMAAfVNc.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6Ail_TXMAAfVNc.jpg',
#       'sizes': {'large': {'h': 1632, 'resize': 'fit', 'w': 1224},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 900},
#        'small': {'h': 680, 'resize': 'fit', 'w': 510},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/Q3mFek73Jv'}]},
#    'favorite_count': 877,
#    'favorited': False,
#    'geo': None,
#    'id': 837707572715094020,
#    'id_str': '837707572715094020',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 374,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'zoom in on my skirt in this picture of me and lexi https://t.co/Q3mFek73Jv',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Aug 21 22:22:23 +0000 2016',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'what in scavenger hunt anticipation',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1402,
#     'follow_request_sent': None,
#     'followers_count': 159,
#     'following': None,
#     'friends_count': 87,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 767487035942854656,
#     'id_str': '767487035942854656',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'messiah college',
#     'name': 'rocky☀️',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/767487035942854656/1488559957',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/837707368020443136/Ppylzz74_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837707368020443136/Ppylzz74_normal.jpg',
#     'profile_link_color': 'F58EA8',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'yagirlrocks',
#     'statuses_count': 644,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @yagirlrocks: zoom in on my skirt in this picture of me and lexi https://t.co/Q3mFek73Jv',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jun 01 18:18:34 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '♀| J. Dalmau❤️ | #blacklivesmatter | 🏳️\u200d🌈',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 19533,
#    'follow_request_sent': None,
#    'followers_count': 909,
#    'following': None,
#    'friends_count': 541,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 1475367386,
#    'id_str': '1475367386',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3,
#    'location': 'MIA',
#    'name': 'ellena',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1475367386/1487629882',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/826615034516213770/ibR1ZRLg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826615034516213770/ibR1ZRLg_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'ellenfinale',
#    'statuses_count': 14792,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:14:41 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811676358787072,
#   'id_str': '839811676358787072',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#   'text': 'Good Morning Everyone 😎😎😎 — feeling fabulous',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jul 23 20:32:21 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Music Producer/Rapper/Engineer out of Harrisburg, PA. For Booking email: vinnymactheprince@gmail.com! #4Duub #OTWG #MacMachine #717 \ue42a\ue42b\ue12f\ue104\ue126\ue326\ue03e\ue330\ue307\ue11d\ue00e\ue404',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'reverbnation.com/realvinnymac',
#        'expanded_url': 'http://www.reverbnation.com/realvinnymac',
#        'indices': [0, 22],
#        'url': 'http://t.co/yPdCSS7nm0'}]}},
#    'favourites_count': 195,
#    'follow_request_sent': None,
#    'followers_count': 1293,
#    'following': None,
#    'friends_count': 301,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 59580010,
#    'id_str': '59580010',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Harrisburg, PA',
#    'name': 'MaC sAuCe!',
#    'notifications': None,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/59580010/1430424704',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/707214806235754496/Mlkwzcei_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/707214806235754496/Mlkwzcei_normal.jpg',
#    'profile_link_color': 'EB2F2F',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '91C71C',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'realvinnymac',
#    'statuses_count': 23535,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/yPdCSS7nm0',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:14:38 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/A7Cwfs',
#      'expanded_url': 'http://bit.ly/A7Cwfs',
#      'indices': [81, 104],
#      'url': 'https://t.co/hxtNOCLGxT'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811663670882304,
#   'id_str': '839811663670882304',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.twittascope.com" rel="nofollow">Twittascope</a>',
#   'text': 'You might question if you were ever on the same page as a frie... More for Virgo https://t.co/hxtNOCLGxT',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Feb 08 17:26:29 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'beauty in the struggle',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 10177,
#    'follow_request_sent': None,
#    'followers_count': 771,
#    'following': None,
#    'friends_count': 675,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 112483709,
#    'id_str': '112483709',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'York, PA',
#    'name': 'Raphy',
#    'notifications': None,
#    'profile_background_color': 'ACDED6',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000066361721/d74a1240ddf04432002ce0bcb081328b.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000066361721/d74a1240ddf04432002ce0bcb081328b.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/112483709/1486671649',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/837479061173698560/0w5VWYi5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837479061173698560/0w5VWYi5_normal.jpg',
#    'profile_link_color': '038543',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F6F6F6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Raphy_A35',
#    'statuses_count': 23279,
#    'time_zone': 'Central Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -21600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:14:28 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'nytimes.com/2017/03/08/us/…',
#      'expanded_url': 'http://www.nytimes.com/2017/03/08/us/justice-department-cia-psychologists-interrogation-program.html',
#      'indices': [85, 108],
#      'url': 'https://t.co/z4Tztrnak5'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811622319316992,
#   'id_str': '839811622319316992',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'Criminal\n"State Secrets Privilege Invoked to Block Testimony in C.I.A. Torture Case" https://t.co/z4Tztrnak5',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Oct 25 20:45:18 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Prof of History @Dickinson College USA. Author: From Ruins to Reconstruction: Urban Identity in Sevastopol after WWII http://t.co/SiBq5l9ULI RT not endorsement.',
#    'entities': {'description': {'urls': [{'display_url': 'goo.gl/pIDiim',
#        'expanded_url': 'http://goo.gl/pIDiim',
#        'indices': [118, 140],
#        'url': 'http://t.co/SiBq5l9ULI'}]},
#     'url': {'urls': [{'display_url': 'blogs.dickinson.edu/karlqualls',
#        'expanded_url': 'http://blogs.dickinson.edu/karlqualls',
#        'indices': [0, 23],
#        'url': 'https://t.co/lRb5fgjCzc'}]}},
#    'favourites_count': 642,
#    'follow_request_sent': None,
#    'followers_count': 432,
#    'following': None,
#    'friends_count': 346,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 16971227,
#    'id_str': '16971227',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 22,
#    'location': 'Carlisle, PA',
#    'name': 'Karl Qualls',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/438337707257774081/BErLYnWe.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/438337707257774081/BErLYnWe.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16971227/1398359471',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/753676786341412864/5CvPJ9mg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/753676786341412864/5CvPJ9mg_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'prof4russia',
#    'statuses_count': 5998,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/lRb5fgjCzc',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:14:13 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#      'expanded_url': 'https://twitter.com/i/web/status/839811558158974976',
#      'indices': [106, 129],
#      'url': 'https://t.co/ie9YG1qFoG'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811558158974976,
#   'id_str': '839811558158974976',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#   'text': 'Credit Repair in Arizona: Free Credit Repair Consultation in\xa0Arizona call (888) 502-1260 fix bad credit…… https://t.co/ie9YG1qFoG',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu May 14 04:39:16 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Credit Repair in Harrisburg Pennsylvania 17101 call (888) 502-1260       https://t.co/SpPmzjzYEm       https://t.co/1QWaNZEN9p       https://t.co/rZzb9nxMWe',
#    'entities': {'description': {'urls': [{'display_url': 'facebook.com/Credit-Repair-…',
#        'expanded_url': 'https://www.facebook.com/Credit-Repair-in-Pennsylvania-338430203194513/',
#        'indices': [73, 96],
#        'url': 'https://t.co/SpPmzjzYEm'},
#       {'display_url': 'es-la.facebook.com/Credit-Repair-…',
#        'expanded_url': 'https://es-la.facebook.com/Credit-Repair-in-Pennsylvania-338430203194513/',
#        'indices': [103, 126],
#        'url': 'https://t.co/1QWaNZEN9p'},
#       {'display_url': 'm.facebook.com/Credit-Repair-…',
#        'expanded_url': 'https://m.facebook.com/Credit-Repair-in-Pennsylvania-338430203194513/',
#        'indices': [133, 156],
#        'url': 'https://t.co/rZzb9nxMWe'}]},
#     'url': {'urls': [{'display_url': 'facebook.com/Credit-Repair-…',
#        'expanded_url': 'https://www.facebook.com/Credit-Repair-in-Pennsylvania-338430203194513/',
#        'indices': [0, 23],
#        'url': 'https://t.co/SpPmzjzYEm'}]}},
#    'favourites_count': 3,
#    'follow_request_sent': None,
#    'followers_count': 5,
#    'following': None,
#    'friends_count': 0,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 3253068725,
#    'id_str': '3253068725',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Harrisburg PA',
#    'name': 'Harrisburg PA',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/802946529807962112/yRLbmyDq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/802946529807962112/yRLbmyDq_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'tsaoinnyana',
#    'statuses_count': 1274,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/SpPmzjzYEm',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:14:06 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 455552476,
#      'id_str': '455552476',
#      'indices': [0, 16],
#      'name': 'Fred Clark',
#      'screen_name': 'SlacktivistFred'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811532116623361,
#   'id_str': '839811532116623361',
#   'in_reply_to_screen_name': 'SlacktivistFred',
#   'in_reply_to_status_id': 839723340390625280,
#   'in_reply_to_status_id_str': '839723340390625280',
#   'in_reply_to_user_id': 455552476,
#   'in_reply_to_user_id_str': '455552476',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.twitter.com" rel="nofollow">Twitter for Windows</a>',
#   'text': "@SlacktivistFred wow, I thought they'd been gone for years now",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Dec 07 02:05:45 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 14988,
#    'follow_request_sent': None,
#    'followers_count': 67,
#    'following': None,
#    'friends_count': 61,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 2233791876,
#    'id_str': '2233791876',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 22,
#    'location': 'Harrisburg, PA',
#    'name': 'Jeremy Z.',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/535850375513780224/l_G8vM9j_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/535850375513780224/l_G8vM9j_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Zoutaleaux',
#    'statuses_count': 14572,
#    'time_zone': 'Atlantic Time (Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -14400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:14:05 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'huffingtonpost.com/entry/justice-…',
#      'expanded_url': 'http://www.huffingtonpost.com/entry/justice-breyer-dissent-solitary-confinement_us_58c082e3e4b054a0ea679cf9?ncid=engmodushpmg00000004',
#      'indices': [80, 103],
#      'url': 'https://t.co/DLbx5Tejjf'}],
#    'user_mentions': [{'id': 15458694,
#      'id_str': '15458694',
#      'indices': [108, 120],
#      'name': 'HuffPost Politics',
#      'screen_name': 'HuffPostPol'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811525158240257,
#   'id_str': '839811525158240257',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'In a late-night dissent, Justice Breyer sounds off against solitary confinement https://t.co/DLbx5Tejjf via @HuffPostPol',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jun 30 21:35:48 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Am 63 year old, retiree, live on a shoe string, believe in making changes today.  Occupy everything.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1998,
#    'follow_request_sent': None,
#    'followers_count': 1213,
#    'following': None,
#    'friends_count': 2426,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 327022004,
#    'id_str': '327022004',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 61,
#    'location': 'Harrisburg, Pa',
#    'name': 'jackie',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/692919625533800448/hLGauNKE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/692919625533800448/hLGauNKE_normal.jpg',
#    'profile_link_color': 'DD2E44',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'GeminijlwWilson',
#    'statuses_count': 37062,
#    'time_zone': 'Atlantic Time (Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -14400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 09 12:14:00 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2937905451,
#      'id_str': '2937905451',
#      'indices': [0, 13],
#      'name': 'كاميليا ورد',
#      'screen_name': 'wardkamilya1'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839811507177275392,
#   'id_str': '839811507177275392',
#   'in_reply_to_screen_name': 'wardkamilya1',
#   'in_reply_to_status_id': 839562835164344324,
#   'in_reply_to_status_id_str': '839562835164344324',
#   'in_reply_to_user_id': 2937905451,
#   'in_reply_to_user_id_str': '2937905451',
#   'is_quote_status': False,
#   'lang': 'ar',
#   'metadata': {'iso_language_code': 'ar', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@wardkamilya1 كل عام وانتي بمليون خير يا احلا بنت وأجمل امرأة ❤️❤️❤️❤️',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jan 02 10:56:20 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 74,
#    'follow_request_sent': None,
#    'followers_count': 2,
#    'following': None,
#    'friends_count': 19,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 815874361328603136,
#    'id_str': '815874361328603136',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ar',
#    'listed_count': 0,
#    'location': 'Lebanon, PA',
#    'name': 'Jojo Pop',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/815874361328603136/1486835014',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/830472184665616386/Rthe2hsR_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830472184665616386/Rthe2hsR_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JojoPop16',
#    'statuses_count': 35,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 10
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-37ced817fd2a> in <module>()
#       2 file_dir = "data" # Set this to where your JSON saved
#       3 # Get only the JSONs we have saved
# ----> 4 onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]
#       5
#       6 # create an empty dataframe with columns for each property
#
# NameError: name 'listdir' is not defined

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['', 'Lebanon, PA', 'Planet Earth', 'York, PA', 'Harrisburg, PA',
#        'United States', 'Hershey, PA', 'harrisburg pa',
#        'Hershey High School', 'Harrisburg,  PA'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                              Count
# Location
#                                  3
# Arkansas, USA                    1
# En tu corazon                    1
# Harrisburg                       1
# Harrisburg PA                    1
# Harrisburg,  PA                  1
# Harrisburg, PA                   5
# Hershey High School              1
# Hershey, PA                      1
# Lebanon, PA                      2
# Pennsylvania                     1
# Perkasie, Pa                     1
# Planet Earth                     1
# Shiremanstown, Pennsylvania      1
# United States                    1
# York, PA                         4
# harrisburg , PA                  1
# harrisburg pa                    1
# ÜT: 40.256558,-76.859515         1

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
# Empty DataFrame
# Columns: [tweet_id, lat, lon, content, location, user, raw_source, data_point, time]
# Index: []

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-1dff57db92fa> in <module>()
#       1 # Use a scatter plot to make a quick visualization of the data points
#       2 # NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
# ----> 3 plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
#       4 plt.show()
#
# /Users/Danya/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/Danya/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/Danya/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3993         maskargs = x, y, s, c, colors, edgecolors, linewidths
#    3994         x, y, s, c, colors, edgecolors, linewidths =\
# -> 3995             cbook.delete_masked_points(*maskargs)
#    3996
#    3997         scales = s   # Renamed for readability below.
#
# /Users/Danya/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py in delete_masked_points(*args)
#    1834         return ()
#    1835     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1836         raise ValueError("First argument must be a sequence")
#    1837     nrecs = len(args[0])
#    1838     margs = []
#
# ValueError: First argument must be a sequence

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_york = ['York, PA','York PA','York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_york, 'York, PA')

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
