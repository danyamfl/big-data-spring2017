# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[40.261455,-76.882553] # Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:55 +0000 2017',
#   'entities': {'hashtags': [{'indices': [46, 55], 'text': 'MiniTHON'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2458040166,
#      'id_str': '2458040166',
#      'indices': [3, 16],
#      'name': 'Four Diamonds',
#      'screen_name': 'fourdiamonds'},
#     {'id': 31115798,
#      'id_str': '31115798',
#      'indices': [68, 73],
#      'name': 'Penn State THON™',
#      'screen_name': 'THON'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743196498857984,
#   'id_str': '838743196498857984',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 9,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 01:50:08 +0000 2017',
#    'entities': {'hashtags': [{'indices': [28, 37], 'text': 'MiniTHON'}],
#     'symbols': [],
#     'urls': [{'display_url': 'youtu.be/-gZ_dj7lkDU',
#       'expanded_url': 'https://youtu.be/-gZ_dj7lkDU',
#       'indices': [100, 123],
#       'url': 'https://t.co/Dld2Uzl9OV'}],
#     'user_mentions': [{'id': 31115798,
#       'id_str': '31115798',
#       'indices': [50, 55],
#       'name': 'Penn State THON™',
#       'screen_name': 'THON'}]},
#    'favorite_count': 15,
#    'favorited': False,
#    'geo': None,
#    'id': 838567340623204353,
#    'id_str': '838567340623204353',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 9,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': "Here's a special message to #MiniTHON for helping @THON and Four Diamonds conquer childhood cancer! https://t.co/Dld2Uzl9OV",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Apr 22 12:10:31 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The Four Diamonds mission is to conquer childhood cancer by supporting world-class care and life-saving research to benefit kids everywhere. #FTK',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'fourdiamonds.org',
#         'expanded_url': 'http://www.fourdiamonds.org',
#         'indices': [0, 23],
#         'url': 'https://t.co/WsO1oL7nzk'}]}},
#     'favourites_count': 2721,
#     'follow_request_sent': None,
#     'followers_count': 6191,
#     'following': None,
#     'friends_count': 1018,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 2458040166,
#     'id_str': '2458040166',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 25,
#     'location': 'Hershey, PA',
#     'name': 'Four Diamonds',
#     'notifications': None,
#     'profile_background_color': '003896',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2458040166/1487546493',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/771079991387787264/ftzx3RQM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/771079991387787264/ftzx3RQM_normal.jpg',
#     'profile_link_color': '003896',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'fourdiamonds',
#     'statuses_count': 8549,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/WsO1oL7nzk',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "RT @fourdiamonds: Here's a special message to #MiniTHON for helping @THON and Four Diamonds conquer childhood cancer! https://t.co/Dld2Uzl9…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Dec 06 03:52:59 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "For the Kids who don't have the chance.Smiles Make The World Go Round. PSU'18 #FightLikeHill #3Peat #ForJacob #FTK #Survivor",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'bradyclucasgolfouting.org',
#        'expanded_url': 'http://bradyclucasgolfouting.org',
#        'indices': [0, 23],
#        'url': 'https://t.co/oDZe2U99k4'}]}},
#    'favourites_count': 5884,
#    'follow_request_sent': None,
#    'followers_count': 1457,
#    'following': None,
#    'friends_count': 989,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 429569930,
#    'id_str': '429569930',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 20,
#    'location': '',
#    'name': 'Brady Lucas',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/429569930/1480081660',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/808331408246734848/5w5ZtJmZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/808331408246734848/5w5ZtJmZ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'bradyluu',
#    'statuses_count': 29761,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/oDZe2U99k4',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:42 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/RadioVIslam/st…',
#      'expanded_url': 'https://twitter.com/RadioVIslam/status/838330102559698944',
#      'indices': [34, 57],
#      'url': 'https://t.co/pxWTlFvWYQ'}],
#    'user_mentions': [{'id': 54251340,
#      'id_str': '54251340',
#      'indices': [3, 10],
#      'name': 'Saira Niz',
#      'screen_name': 'sainiz'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743142014849025,
#   'id_str': '838743142014849025',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status_id': 838330102559698944,
#   'quoted_status_id_str': '838330102559698944',
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 13:06:40 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/RadioVIslam/st…',
#       'expanded_url': 'https://twitter.com/RadioVIslam/status/838330102559698944',
#       'indices': [22, 45],
#       'url': 'https://t.co/pxWTlFvWYQ'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 838737595098091520,
#    'id_str': '838737595098091520',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sun Mar 05 10:07:26 +0000 2017',
#     'entities': {'hashtags': [{'indices': [3, 16], 'text': 'TheHolyQuran'},
#       {'indices': [50, 57], 'text': 'future'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#        'expanded_url': 'https://twitter.com/i/web/status/838330102559698944',
#        'indices': [111, 134],
#        'url': 'https://t.co/W8o2ZABUZZ'}],
#      'user_mentions': []},
#     'favorite_count': 11,
#     'favorited': False,
#     'geo': None,
#     'id': 838330102559698944,
#     'id_str': '838330102559698944',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 20,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'In #TheHolyQuran it is promised that whatever the #future holds will be better for you than what has gone by.… https://t.co/W8o2ZABUZZ',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Sep 14 07:20:58 +0000 2015',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': "The Voice of Islam Live on DAB Radio & Online. News, Views, Discussion and an Insight into Islam's perspectives of the World Today.",
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'VoiceOfIslam.co.uk',
#          'expanded_url': 'http://VoiceOfIslam.co.uk',
#          'indices': [0, 23],
#          'url': 'https://t.co/BkErrpVb2S'}]}},
#      'favourites_count': 170,
#      'follow_request_sent': None,
#      'followers_count': 3785,
#      'following': None,
#      'friends_count': 144,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 3650610317,
#      'id_str': '3650610317',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en-gb',
#      'listed_count': 34,
#      'location': 'London, England',
#      'name': 'Voice Of Islam',
#      'notifications': None,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3650610317/1446916123',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/663040775551328257/TnZu-TmQ_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/663040775551328257/TnZu-TmQ_normal.jpg',
#      'profile_link_color': '89C9FA',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'RadioVIslam',
#      'statuses_count': 4236,
#      'time_zone': 'London',
#      'translator_type': 'none',
#      'url': 'https://t.co/BkErrpVb2S',
#      'utc_offset': 0,
#      'verified': False}},
#    'quoted_status_id': 838330102559698944,
#    'quoted_status_id_str': '838330102559698944',
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'A very kind reminder. https://t.co/pxWTlFvWYQ',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jul 06 16:20:45 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Woes and wonders of Power, that tonic hell, synthesis of poison and panacea. -Emile M. Cioran',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'sainizz.wordpress.com',
#         'expanded_url': 'http://sainizz.wordpress.com/',
#         'indices': [0, 23],
#         'url': 'https://t.co/atroKthYvB'}]}},
#     'favourites_count': 4106,
#     'follow_request_sent': None,
#     'followers_count': 2877,
#     'following': None,
#     'friends_count': 436,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 54251340,
#     'id_str': '54251340',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 36,
#     'location': 'Harrisburg, PA',
#     'name': 'Saira Niz',
#     'notifications': None,
#     'profile_background_color': 'FBDEC0',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000119784597/a149f6d017b7a37c7ce88095c85b10e7.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000119784597/a149f6d017b7a37c7ce88095c85b10e7.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/54251340/1481275624',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/820857871374094336/uk-AgIWU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/820857871374094336/uk-AgIWU_normal.jpg',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '85353A',
#     'profile_text_color': 'AC5256',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'sainiz',
#     'statuses_count': 41892,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'regular',
#     'url': 'https://t.co/atroKthYvB',
#     'utc_offset': -21600,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @sainiz: A very kind reminder. https://t.co/pxWTlFvWYQ',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Mar 15 06:49:34 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Lover of Nature, Science, Astronomy, Maths,  Humanity and God. Not Ahmadi by birth only but also after study and reflection. Islam is my religion.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 2492,
#    'follow_request_sent': None,
#    'followers_count': 282,
#    'following': None,
#    'friends_count': 1328,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 266437259,
#    'id_str': '266437259',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 41,
#    'location': '',
#    'name': 'Waseem joolfoo',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/266437259/1447784661',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/760512667085930496/cNiuoOGI_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760512667085930496/cNiuoOGI_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Zul10000',
#    'statuses_count': 9431,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:36 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'fb.me/4R8PXKPJr',
#      'expanded_url': 'http://fb.me/4R8PXKPJr',
#      'indices': [116, 139],
#      'url': 'https://t.co/pQ18Xwr1M8'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743115997532161,
#   'id_str': '838743115997532161',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#   'text': 'It\'s always nice to hear from a customer after they\'ve gotten to put their new install to the test!\n\n"Greg, it\'s... https://t.co/pQ18Xwr1M8',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jan 15 16:37:25 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'easternelectricalsystems.com',
#        'expanded_url': 'http://www.easternelectricalsystems.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/Nyu8I9OCRx'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 6,
#    'following': None,
#    'friends_count': 3,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 238625288,
#    'id_str': '238625288',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Lebanon, PA',
#    'name': 'Eastern Systems',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/238625288/1403014477',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/753311464409206784/Y8oNkA6S_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/753311464409206784/Y8oNkA6S_normal.jpg',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'easternsystems',
#    'statuses_count': 36,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/Nyu8I9OCRx',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:28 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 283723554,
#      'id_str': '283723554',
#      'indices': [3, 15],
#      'name': 'John Raymond Hanger',
#      'screen_name': 'johnrhanger'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743082094972928,
#   'id_str': '838743082094972928',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 13:27:03 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/838742724471832576',
#       'indices': [117, 140],
#       'url': 'https://t.co/s4HtUGozuJ'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 838742724471832576,
#    'id_str': '838742724471832576',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://www.twitter.com" rel="nofollow">Twitter for Windows</a>',
#    'text': '2016 Wind total capacity exceeds hydro capacity. Capacity factor for wind in 2016 was 34.7%; hydro 38%. Hydro can g… https://t.co/s4HtUGozuJ',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Apr 17 22:04:36 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Energy, environment, politics. Former Sec. of Policy, Sec. Pa DEP, Com. Pa. PUC, Dem candidate for Governor. Grad: Duke & Penn. hangerconsultingllc@gmail.com',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1981,
#     'follow_request_sent': None,
#     'followers_count': 2272,
#     'following': None,
#     'friends_count': 187,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 283723554,
#     'id_str': '283723554',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 140,
#     'location': 'Hershey Pa',
#     'name': 'John Raymond Hanger',
#     'notifications': None,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1734167906/John_Hanger_sm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1734167906/John_Hanger_sm_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'johnrhanger',
#     'statuses_count': 5706,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'text': 'RT @johnrhanger: 2016 Wind total capacity exceeds hydro capacity. Capacity factor for wind in 2016 was 34.7%; hydro 38%. Hydro can go over…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 17 11:54:22 +0000 2015',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Passionate about #SustainableEnergy, #EnergyDemocracy & #ClimateAction. Future is 100% #Renewable because #go100RE is actually inevitable. All views my own.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 21072,
#    'follow_request_sent': None,
#    'followers_count': 543,
#    'following': None,
#    'friends_count': 766,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 3042384586,
#    'id_str': '3042384586',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en-gb',
#    'listed_count': 202,
#    'location': 'Planet Earth',
#    'name': 'Sandro Benz',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3042384586/1451223665',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/681101837383106561/RyeAxYl5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/681101837383106561/RyeAxYl5_normal.jpg',
#    'profile_link_color': '18CF35',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'sandro_benz',
#    'statuses_count': 6498,
#    'time_zone': 'Stockholm',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 3600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:24 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743066588692480,
#   'id_str': '838743066588692480',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'All I want is some chocolate chip pancakes 😕',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat May 16 04:00:45 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'snapchat// adrianna_westt',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 790,
#    'follow_request_sent': None,
#    'followers_count': 232,
#    'following': None,
#    'friends_count': 351,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 3259155731,
#    'id_str': '3259155731',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'York, PA',
#    'name': 'Adrianna',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3259155731/1487700852',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834126798585810944/rOUm9xF8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/834126798585810944/rOUm9xF8_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'adriannawest9',
#    'statuses_count': 1585,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:23 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'youtu.be/cb8y39KQZRE?a',
#      'expanded_url': 'http://youtu.be/cb8y39KQZRE?a',
#      'indices': [25, 48],
#      'url': 'https://t.co/KCkEFrhJjU'}],
#    'user_mentions': [{'id': 10228272,
#      'id_str': '10228272',
#      'indices': [10, 18],
#      'name': 'YouTube',
#      'screen_name': 'YouTube'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743061849047041,
#   'id_str': '838743061849047041',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': True,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.google.com/" rel="nofollow">Google</a>',
#   'text': 'I liked a @YouTube video https://t.co/KCkEFrhJjU Kellyanne Conway Can’t Confirm If Donald trump Definitely Knows He Was Wiretapped',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Nov 08 15:31:46 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Originally Based in Harrisburg Pennsylvania, now the Philippines Cycle Forward Films is poised to emerge as a major producer of filmed content for the world.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'cycleforwardfilms.com',
#        'expanded_url': 'http://www.cycleforwardfilms.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/xJDdrZ6kdk'}]}},
#    'favourites_count': 211,
#    'follow_request_sent': None,
#    'followers_count': 466,
#    'following': None,
#    'friends_count': 2004,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 407799877,
#    'id_str': '407799877',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 17,
#    'location': 'Harrisburg, PA',
#    'name': 'Cycle Forward Films',
#    'notifications': None,
#    'profile_background_color': '8B542B',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/407799877/1463672074',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1628960317/cycleforwardlogo_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1628960317/cycleforwardlogo_normal.jpg',
#    'profile_link_color': '9D582E',
#    'profile_sidebar_border_color': 'D9B17E',
#    'profile_sidebar_fill_color': 'EADEAA',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'CycleForward',
#    'statuses_count': 16278,
#    'time_zone': 'Central Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/xJDdrZ6kdk',
#    'utc_offset': -21600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:18 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#      'expanded_url': 'https://twitter.com/i/web/status/838743039887704064',
#      'indices': [117, 140],
#      'url': 'https://t.co/fQJznhr9am'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743039887704064,
#   'id_str': '838743039887704064',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-76.944227, 40.2298234],
#       [-76.906489, 40.2298234],
#       [-76.906489, 40.25942],
#       [-76.944227, 40.25942]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Camp Hill, PA',
#    'id': 'a93638d9055b5624',
#    'name': 'Camp Hill',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/a93638d9055b5624.json'},
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 05:13:33 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/838618531428188165',
#       'indices': [117, 140],
#       'url': 'https://t.co/O5OQGpZj70'}],
#     'user_mentions': []},
#    'favorite_count': 12,
#    'favorited': False,
#    'geo': None,
#    'id': 838618531428188165,
#    'id_str': '838618531428188165',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status_id': 838432922881376257,
#    'quoted_status_id_str': '838432922881376257',
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '"Where do you go to school?"\n"Indiana University..."\n"Oh I love the Hoosiers!"\n"of Pennsylvania"\n"...."\n".......it\'… https://t.co/O5OQGpZj70',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Jul 18 01:17:51 +0000 2010',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'rad never sad #CLE',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 3020,
#     'follow_request_sent': None,
#     'followers_count': 439,
#     'following': None,
#     'friends_count': 419,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 167967032,
#     'id_str': '167967032',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': "IUP '17",
#     'name': 'Alex Conces',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/167967032/1460222325',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/828017086802886657/1AE26KBU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/828017086802886657/1AE26KBU_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'a_cons',
#     'statuses_count': 3114,
#     'time_zone': 'Quito',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -18000,
#     'verified': False}},
#   'quoted_status_id': 838618531428188165,
#   'quoted_status_id_str': '838618531428188165',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '"Where are you from?"\n"Dillsburg"\n"Wut"\n"Like the pickle"\n"Where?"\n"Harrisburg, pa" \n"I don\'t know where that is, S… https://t.co/fQJznhr9am',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Aug 06 20:17:21 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Indiana University of Pennsylvania Graduate. |-/ officially woke. Truth the Process',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3742,
#    'follow_request_sent': None,
#    'followers_count': 728,
#    'following': None,
#    'friends_count': 499,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 349852027,
#    'id_str': '349852027',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 5,
#    'location': 'United States',
#    'name': 'Tony Reed',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/349852027/1488769159',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/825561207847452672/fpaufpJD_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/825561207847452672/fpaufpJD_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Tony_Reed07',
#    'statuses_count': 15090,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:17 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3893251942,
#      'id_str': '3893251942',
#      'indices': [0, 11],
#      'name': 'GameLining',
#      'screen_name': 'GameLining'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743036259631104,
#   'id_str': '838743036259631104',
#   'in_reply_to_screen_name': 'GameLining',
#   'in_reply_to_status_id': 838742605127172096,
#   'in_reply_to_status_id_str': '838742605127172096',
#   'in_reply_to_user_id': 3893251942,
#   'in_reply_to_user_id_str': '3893251942',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '@GameLining Thanks!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Sep 22 13:20:56 +0000 2016',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Owner of FunGamingNetwork.Leader of competitve divisions of FGN. Xbox Competitive COD player for D4E. (Die4Equality) https://t.co/VMAFEUqqNR',
#    'entities': {'description': {'urls': [{'display_url': 'fungamingnetwork.com',
#        'expanded_url': 'http://fungamingnetwork.com',
#        'indices': [117, 140],
#        'url': 'https://t.co/VMAFEUqqNR'}]},
#     'url': {'urls': [{'display_url': 'youtube.com/c/MrsRageAlot85',
#        'expanded_url': 'https://www.youtube.com/c/MrsRageAlot85',
#        'indices': [0, 23],
#        'url': 'https://t.co/HEDtxTa357'}]}},
#    'favourites_count': 3824,
#    'follow_request_sent': None,
#    'followers_count': 1175,
#    'following': None,
#    'friends_count': 1090,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 778947187975811072,
#    'id_str': '778947187975811072',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 11,
#    'location': 'Hershey, PA',
#    'name': 'MrsRageAlot85',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/778947187975811072/1488742667',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/836350274008670208/Cq1Xc6o4_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/836350274008670208/Cq1Xc6o4_normal.jpg',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'MrsRageAlot85',
#    'statuses_count': 2979,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/HEDtxTa357',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:15 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'abc27.com/2017/03/03/tic…',
#      'expanded_url': 'http://abc27.com/2017/03/03/tick-talk-how-lyme-disease-has-more-reach-than-hivaids/',
#      'indices': [109, 132],
#      'url': 'https://t.co/2jAzTx0MEc'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743027275415552,
#   'id_str': '838743027275415552',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Almost cried a few times while we were recording this special edition of our podcast. Heart-wrenching stuff. https://t.co/2jAzTx0MEc',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Oct 04 22:59:22 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Investigative reporter for @abc27news in Harrisburg, PA. Proud graduate of @SyracuseU. I love my family, coffee, and all things news.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'abc27.com',
#        'expanded_url': 'http://abc27.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/wh7B6lGLqq'}]}},
#    'favourites_count': 1191,
#    'follow_request_sent': None,
#    'followers_count': 2049,
#    'following': None,
#    'friends_count': 2101,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 79853059,
#    'id_str': '79853059',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 50,
#    'location': 'Harrisburg, PA',
#    'name': 'Amanda St. Hilaire',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79853059/1477503016',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/615985027919122432/nibIqbrH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/615985027919122432/nibIqbrH_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'AmandaABC27',
#    'statuses_count': 3671,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
#    'url': 'https://t.co/wh7B6lGLqq',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:14 +0000 2017',
#   'entities': {'hashtags': [{'indices': [33, 38], 'text': 'VSCO'}],
#    'symbols': [],
#    'urls': [{'display_url': 'vsco.co/livileon/colle…',
#      'expanded_url': 'https://vsco.co/livileon/collection',
#      'indices': [39, 62],
#      'url': 'https://t.co/lbXamsuMuT'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743022372327427,
#   'id_str': '838743022372327427',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'View this Collection by livileon #VSCO https://t.co/lbXamsuMuT',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Dec 31 04:52:22 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "ldhs '18",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1396,
#    'follow_request_sent': None,
#    'followers_count': 303,
#    'following': None,
#    'friends_count': 605,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 451201942,
#    'id_str': '451201942',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'harrisburg pa',
#    'name': 'gracie unger ☯',
#    'notifications': None,
#    'profile_background_color': '00FCEF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/451201942/1488200713',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/832295967831502849/cPVAm2ok_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/832295967831502849/cPVAm2ok_normal.jpg',
#    'profile_link_color': '0015FF',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '7AC3EE',
#    'profile_text_color': '3D1957',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'gracieunger13',
#    'statuses_count': 1527,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:13 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/fillwerrell/st…',
#      'expanded_url': 'https://twitter.com/fillwerrell/status/838594830292824064',
#      'indices': [45, 68],
#      'url': 'https://t.co/TkBqxZRF9T'}],
#    'user_mentions': [{'id': 979313725,
#      'id_str': '979313725',
#      'indices': [32, 44],
#      'name': 'Jules',
#      'screen_name': 'HelloJulia1'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743020405153793,
#   'id_str': '838743020405153793',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 03:39:22 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/kjFZ1yLPM0',
#       'expanded_url': 'https://twitter.com/terracid/status/829050814605955072/video/1',
#       'id': 829050395477544961,
#       'id_str': '829050395477544961',
#       'indices': [39, 62],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/829050395477544961/pu/img/hTmTl-moCkVmpWs4.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/829050395477544961/pu/img/hTmTl-moCkVmpWs4.jpg',
#       'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#        'small': {'h': 191, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 829050814605955072,
#       'source_status_id_str': '829050814605955072',
#       'source_user_id': 80410029,
#       'source_user_id_str': '80410029',
#       'type': 'photo',
#       'url': 'https://t.co/kjFZ1yLPM0'}],
#     'symbols': [],
# ...
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 4937,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'WHY DID HE SAY CALL 911 I CANT BREATHE https://t.co/kjFZ1yLPM0',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Oct 06 20:28:14 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Follow for funny tweets! (I am NOT Will Ferrell ~ This is a parody account ~ Not in any way affiliated with the actor Will Ferrell) 📬FillWerrell@yahoo.com',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1027,
#     'follow_request_sent': None,
#     'followers_count': 2828559,
#     'following': None,
#     'friends_count': 1,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 386189099,
#     'id_str': '386189099',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2934,
#     'location': '',
#     'name': 'Fill Werrell',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/819229153/6e5d159eb21817b0da2bb127fb9a0cf9.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/819229153/6e5d159eb21817b0da2bb127fb9a0cf9.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/386189099/1488342790',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/816335691340779521/jjgDlbWJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/816335691340779521/jjgDlbWJ_normal.jpg',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'FillWerrell',
#     'statuses_count': 15389,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'regular',
#     'url': None,
#     'utc_offset': -28800,
#     'verified': False}},
#   'quoted_status_id': 838594830292824064,
#   'quoted_status_id_str': '838594830292824064',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'I think I just pissed myself 😂😂 @HelloJulia1 https://t.co/TkBqxZRF9T',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Oct 19 22:42:46 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '@blouchy_02 ♡',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'vsco.co/carrrrly',
#        'expanded_url': 'http://vsco.co/carrrrly',
#        'indices': [0, 23],
#        'url': 'https://t.co/9at2nl9UR9'}]}},
#    'favourites_count': 5566,
#    'follow_request_sent': None,
#    'followers_count': 489,
#    'following': None,
#    'friends_count': 349,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 2865947936,
#    'id_str': '2865947936',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 4,
#    'location': 'Lebanon, PA',
#    'name': 'carly',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2865947936/1488510341',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/831700107355619329/rn_OgX3S_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/831700107355619329/rn_OgX3S_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'carly_sanders14',
#    'statuses_count': 7975,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/9at2nl9UR9',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:11 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 282545479,
#      'id_str': '282545479',
#      'indices': [0, 10],
#      'name': 'Michael Barbaro',
#      'screen_name': 'mikiebarb'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743009952944128,
#   'id_str': '838743009952944128',
#   'in_reply_to_screen_name': 'mikiebarb',
#   'in_reply_to_status_id': 838741408471117824,
#   'in_reply_to_status_id_str': '838741408471117824',
#   'in_reply_to_user_id': 282545479,
#   'in_reply_to_user_id_str': '282545479',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-76.689419, 40.246151],
#       [-76.601027, 40.246151],
#       [-76.601027, 40.302317],
#       [-76.689419, 40.302317]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Hershey, PA',
#    'id': '8647282dba1cee1e',
#    'name': 'Hershey',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/8647282dba1cee1e.json'},
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '@mikiebarb To make money for its shareholders.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jan 07 15:27:17 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Journalism teacher, adviser for The Broadcaster. I tweet interesting news articles and commentary by journalists about the news.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'hhsbroadcaster.com',
#        'expanded_url': 'http://hhsbroadcaster.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/AXUECSZWxW'}]}},
#    'favourites_count': 883,
#    'follow_request_sent': None,
#    'followers_count': 256,
#    'following': None,
#    'friends_count': 409,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 1068577177,
#    'id_str': '1068577177',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 25,
#    'location': 'Hershey High School',
#    'name': 'Mr. Sterner',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1068577177/1441711226',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/591264668468936704/wjmdR_3Y_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/591264668468936704/wjmdR_3Y_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'HHSE120',
#    'statuses_count': 2449,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/AXUECSZWxW',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:10 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743008220692480,
#   'id_str': '838743008220692480',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'My moms so lazy bro 🤔',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat May 16 04:00:45 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'snapchat// adrianna_westt',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 790,
#    'follow_request_sent': None,
#    'followers_count': 232,
#    'following': None,
#    'friends_count': 351,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 3259155731,
#    'id_str': '3259155731',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'York, PA',
#    'name': 'Adrianna',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3259155731/1487700852',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834126798585810944/rOUm9xF8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/834126798585810944/rOUm9xF8_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'adriannawest9',
#    'statuses_count': 1585,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:09 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 839606413,
#      'id_str': '839606413',
#      'indices': [0, 16],
#      'name': 'reneeoconnorfan',
#      'screen_name': 'reneeoconnorfan'},
#     {'id': 219807531,
#      'id_str': '219807531',
#      'indices': [17, 25],
#      'name': 'fllwrs',
#      'screen_name': '_fllwrs'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838743000348037120,
#   'id_str': '838743000348037120',
#   'in_reply_to_screen_name': 'reneeoconnorfan',
#   'in_reply_to_status_id': 838712187816456192,
#   'in_reply_to_status_id_str': '838712187816456192',
#   'in_reply_to_user_id': 839606413,
#   'in_reply_to_user_id_str': '839606413',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "@reneeoconnorfan @_fllwrs I miss Renee O'Connor on TV",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Feb 10 19:55:32 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 145,
#    'follow_request_sent': None,
#    'followers_count': 3,
#    'following': None,
#    'friends_count': 25,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 3028673267,
#    'id_str': '3028673267',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'York, PA',
#    'name': 'Sandy Sharkey',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/780108315070267392/BNf0qy6L_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/780108315070267392/BNf0qy6L_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'sandy_shark69ss',
#    'statuses_count': 149,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 13:28:04 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 779662754160513024,
#      'id_str': '779662754160513024',
#      'indices': [0, 8],
#      'name': 'Quis',
#      'screen_name': 'Quiss__'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838742980504793089,
#   'id_str': '838742980504793089',
#   'in_reply_to_screen_name': 'Quiss__',
#   'in_reply_to_status_id': 838742592829472769,
#   'in_reply_to_status_id_str': '838742592829472769',
#   'in_reply_to_user_id': 779662754160513024,
#   'in_reply_to_user_id_str': '779662754160513024',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@Quiss__ still on season 2..just got to when the ppl from the back of the plane met up wit the front',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Oct 04 00:58:03 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '|#717| Ship U Alum 14|New Twitter| IG: Ya_royal_freshness| Snapchat:Laidbakk_a',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 4409,
#    'follow_request_sent': None,
#    'followers_count': 287,
#    'following': None,
#    'friends_count': 371,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 2803318095,
#    'id_str': '2803318095',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Harrisburg,  PA',
#    'name': 'Marcus Graham',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2803318095/1430006764',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/837043815483604992/xwulowyL_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837043815483604992/xwulowyL_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': '_LaidBackA',
#    'statuses_count': 10546,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 10
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()
# Out:
# At 0 seconds, added 14 new tweets, for a total of 14
# At 5 seconds, added 0 new tweets, for a total of 14
# 14 Tweets retrieved.

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
#                               tweet_id   lat   lon  \
# 838743196498857984  838743196498857984  None  None
# 838743142014849025  838743142014849025  None  None
# 838743115997532161  838743115997532161  None  None
# 838743082094972928  838743082094972928  None  None
# 838743066588692480  838743066588692480  None  None
# 838743061849047041  838743061849047041  None  None
# 838743039887704064  838743039887704064  None  None
# 838743036259631104  838743036259631104  None  None
# 838743027275415552  838743027275415552  None  None
# 838743022372327427  838743022372327427  None  None
# 838743020405153793  838743020405153793  None  None
# 838743009952944128  838743009952944128  None  None
# 838743008220692480  838743008220692480  None  None
# 838743000348037120  838743000348037120  None  None
# 838742980504793089  838742980504793089  None  None
# 838744685661339648  838744685661339648  None  None
# 838744653524516864  838744653524516864  None  None
# 838744601217347584  838744601217347584  None  None
# 838744551753940992  838744551753940992  None  None
# 838744549812027393  838744549812027393  None  None
# 838744525350776832  838744525350776832  None  None
# 838744525132673024  838744525132673024  None  None
# 838744507625717761  838744507625717761  None  None
# 838744494979833856  838744494979833856  None  None
# 838744470577430530  838744470577430530  None  None
# 838744450146910208  838744450146910208  None  None
# 838744398850625537  838744398850625537  None  None
# 838744390587777026  838744390587777026  None  None
# 838744379506450432  838744379506450432  None  None
#
#                                                               content  \
# 838743196498857984  RT @fourdiamonds: Here's a special message to ...
# 838743142014849025  RT @sainiz: A very kind reminder. https://t.co...
# 838743115997532161  It's always nice to hear from a customer after...
# 838743082094972928  RT @johnrhanger: 2016 Wind total capacity exce...
# 838743066588692480       All I want is some chocolate chip pancakes 😕
# 838743061849047041  I liked a @YouTube video https://t.co/KCkEFrhJ...
# 838743039887704064  "Where are you from?"\n"Dillsburg"\n"Wut"\n"Li...
# 838743036259631104                                @GameLining Thanks!
# 838743027275415552  Almost cried a few times while we were recordi...
# 838743022372327427  View this Collection by livileon #VSCO https:/...
# 838743020405153793  I think I just pissed myself 😂😂 @HelloJulia1 h...
# 838743009952944128     @mikiebarb To make money for its shareholders.
# 838743008220692480                              My moms so lazy bro 🤔
# 838743000348037120  @reneeoconnorfan @_fllwrs I miss Renee O'Conno...
# 838742980504793089  @Quiss__ still on season 2..just got to when t...
# 838744685661339648  RT @ydrcom: Sandusky transferred from supermax...
# 838744653524516864                        🤤🤘🏾 https://t.co/xG4U5wVZWh
# 838744601217347584  A cold morning in the wood shop. Must clean th...
# 838744551753940992  RT @Keishlaaaa: Have you ever wanted to ask a ...
# 838744549812027393     Irish People Taste KFC https://t.co/twKTLTmThh
# 838744525350776832                            https://t.co/i04yY0Z0uo
# 838744525132673024  RT @CCFalconSwimmin: Congratulations Eli and C...
# 838744507625717761  Unauthorized immigrants contribute nearly $12 ...
# 838744494979833856  RT @GoMechanicsburg: Boys Basketball will play...
# 838744470577430530  @BoltBus I love traveling with you guys but yo...
# 838744450146910208  RT @PAHumanServices: To report suspected child...
# 838744398850625537      "You are the LORD, you alone." - Nehemiah 9:6
# 838744390587777026  @SkylahhhhM yea like Thursday but they not try...
# 838744379506450432  We are not victims by nature.We are programmed...
#
#                                        location                user  \
# 838743196498857984                                        429569930
# 838743142014849025                                        266437259
# 838743115997532161                  Lebanon, PA           238625288
# 838743082094972928                 Planet Earth          3042384586
# 838743066588692480                     York, PA          3259155731
# 838743061849047041               Harrisburg, PA           407799877
# 838743039887704064                United States           349852027
# 838743036259631104                  Hershey, PA  778947187975811072
# 838743027275415552               Harrisburg, PA            79853059
# 838743022372327427                harrisburg pa           451201942
# 838743020405153793                  Lebanon, PA          2865947936
# 838743009952944128          Hershey High School          1068577177
# 838743008220692480                     York, PA          3259155731
# 838743000348037120                     York, PA          3028673267
# 838742980504793089              Harrisburg,  PA          2803318095
# 838744685661339648                Arkansas, USA  753057780383166464
# 838744653524516864                     York, PA  808042760917893120
# 838744601217347584     ÜT: 40.256558,-76.859515            17543866
# 838744551753940992               En tu corazon            863499805
# 838744549812027393               Harrisburg, PA            39623191
# 838744525350776832               Harrisburg, PA            14953834
# 838744525132673024                 Pennsylvania            34431092
# 838744507625717761               Harrisburg, PA           247083647
# 838744494979833856                                       3031209059
# 838744470577430530                Harrisburg PA            68060228
# 838744450146910208                 Perkasie, Pa            16476132
# 838744398850625537  Shiremanstown, Pennsylvania           582029183
# 838744390587777026              harrisburg , PA           709938382
# 838744379506450432                   Harrisburg           623187826
#
#                                                            raw_source  \
# 838743196498857984  {'created_at': 'Mon Mar 06 13:28:55 +0000 2017...
# 838743142014849025  {'created_at': 'Mon Mar 06 13:28:42 +0000 2017...
# 838743115997532161  {'created_at': 'Mon Mar 06 13:28:36 +0000 2017...
# 838743082094972928  {'created_at': 'Mon Mar 06 13:28:28 +0000 2017...
# 838743066588692480  {'created_at': 'Mon Mar 06 13:28:24 +0000 2017...
# 838743061849047041  {'created_at': 'Mon Mar 06 13:28:23 +0000 2017...
# 838743039887704064  {'created_at': 'Mon Mar 06 13:28:18 +0000 2017...
# 838743036259631104  {'created_at': 'Mon Mar 06 13:28:17 +0000 2017...
# 838743027275415552  {'created_at': 'Mon Mar 06 13:28:15 +0000 2017...
# 838743022372327427  {'created_at': 'Mon Mar 06 13:28:14 +0000 2017...
# 838743020405153793  {'created_at': 'Mon Mar 06 13:28:13 +0000 2017...
# 838743009952944128  {'created_at': 'Mon Mar 06 13:28:11 +0000 2017...
# 838743008220692480  {'created_at': 'Mon Mar 06 13:28:10 +0000 2017...
# 838743000348037120  {'created_at': 'Mon Mar 06 13:28:09 +0000 2017...
# 838742980504793089  {'created_at': 'Mon Mar 06 13:28:04 +0000 2017...
# 838744685661339648  {'created_at': 'Mon Mar 06 13:34:50 +0000 2017...
# 838744653524516864  {'created_at': 'Mon Mar 06 13:34:43 +0000 2017...
# 838744601217347584  {'created_at': 'Mon Mar 06 13:34:30 +0000 2017...
# 838744551753940992  {'created_at': 'Mon Mar 06 13:34:18 +0000 2017...
# 838744549812027393  {'created_at': 'Mon Mar 06 13:34:18 +0000 2017...
# 838744525350776832  {'created_at': 'Mon Mar 06 13:34:12 +0000 2017...
# 838744525132673024  {'created_at': 'Mon Mar 06 13:34:12 +0000 2017...
# 838744507625717761  {'created_at': 'Mon Mar 06 13:34:08 +0000 2017...
# 838744494979833856  {'created_at': 'Mon Mar 06 13:34:05 +0000 2017...
# 838744470577430530  {'created_at': 'Mon Mar 06 13:33:59 +0000 2017...
# 838744450146910208  {'created_at': 'Mon Mar 06 13:33:54 +0000 2017...
# 838744398850625537  {'created_at': 'Mon Mar 06 13:33:42 +0000 2017...
# 838744390587777026  {'created_at': 'Mon Mar 06 13:33:40 +0000 2017...
# 838744379506450432  {'created_at': 'Mon Mar 06 13:33:37 +0000 2017...
#
#                    data_point                            time
# 838743196498857984       none  Mon Mar 06 13:28:55 +0000 2017
# 838743142014849025       none  Mon Mar 06 13:28:42 +0000 2017
# 838743115997532161       none  Mon Mar 06 13:28:36 +0000 2017
# 838743082094972928       none  Mon Mar 06 13:28:28 +0000 2017
# 838743066588692480       none  Mon Mar 06 13:28:24 +0000 2017
# 838743061849047041       none  Mon Mar 06 13:28:23 +0000 2017
# 838743039887704064       none  Mon Mar 06 13:28:18 +0000 2017
# 838743036259631104       none  Mon Mar 06 13:28:17 +0000 2017
# 838743027275415552       none  Mon Mar 06 13:28:15 +0000 2017
# 838743022372327427       none  Mon Mar 06 13:28:14 +0000 2017
# 838743020405153793       none  Mon Mar 06 13:28:13 +0000 2017
# 838743009952944128       none  Mon Mar 06 13:28:11 +0000 2017
# 838743008220692480       none  Mon Mar 06 13:28:10 +0000 2017
# 838743000348037120       none  Mon Mar 06 13:28:09 +0000 2017
# 838742980504793089       none  Mon Mar 06 13:28:04 +0000 2017
# 838744685661339648       none  Mon Mar 06 13:34:50 +0000 2017
# 838744653524516864       none  Mon Mar 06 13:34:43 +0000 2017
# 838744601217347584       none  Mon Mar 06 13:34:30 +0000 2017
# 838744551753940992       none  Mon Mar 06 13:34:18 +0000 2017
# 838744549812027393       none  Mon Mar 06 13:34:18 +0000 2017
# 838744525350776832       none  Mon Mar 06 13:34:12 +0000 2017
# 838744525132673024       none  Mon Mar 06 13:34:12 +0000 2017
# 838744507625717761       none  Mon Mar 06 13:34:08 +0000 2017
# 838744494979833856       none  Mon Mar 06 13:34:05 +0000 2017
# 838744470577430530       none  Mon Mar 06 13:33:59 +0000 2017
# 838744450146910208       none  Mon Mar 06 13:33:54 +0000 2017
# 838744398850625537       none  Mon Mar 06 13:33:42 +0000 2017
# 838744390587777026       none  Mon Mar 06 13:33:40 +0000 2017
# 838744379506450432       none  Mon Mar 06 13:33:37 +0000 2017

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['', 'Lebanon, PA', 'Planet Earth', 'York, PA', 'Harrisburg, PA',
#        'United States', 'Hershey, PA', 'harrisburg pa',
#        'Hershey High School', 'Harrisburg,  PA'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                              Count
# Location
#                                  3
# Arkansas, USA                    1
# En tu corazon                    1
# Harrisburg                       1
# Harrisburg PA                    1
# Harrisburg,  PA                  1
# Harrisburg, PA                   5
# Hershey High School              1
# Hershey, PA                      1
# Lebanon, PA                      2
# Pennsylvania                     1
# Perkasie, Pa                     1
# Planet Earth                     1
# Shiremanstown, Pennsylvania      1
# United States                    1
# York, PA                         4
# harrisburg , PA                  1
# harrisburg pa                    1
# ÜT: 40.256558,-76.859515         1

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
# Empty DataFrame
# Columns: [tweet_id, lat, lon, content, location, user, raw_source, data_point, time]
# Index: []

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-1dff57db92fa> in <module>()
#       1 # Use a scatter plot to make a quick visualization of the data points
#       2 # NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
# ----> 3 plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
#       4 plt.show()
#
# /Users/Danya/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/Danya/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/Danya/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3993         maskargs = x, y, s, c, colors, edgecolors, linewidths
#    3994         x, y, s, c, colors, edgecolors, linewidths =\
# -> 3995             cbook.delete_masked_points(*maskargs)
#    3996
#    3997         scales = s   # Renamed for readability below.
#
# /Users/Danya/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py in delete_masked_points(*args)
#    1834         return ()
#    1835     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1836         raise ValueError("First argument must be a sequence")
#    1837     nrecs = len(args[0])
#    1838     margs = []
#
# ValueError: First argument must be a sequence

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_york = ['York, PA','York PA','York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_york, 'York, PA')

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
